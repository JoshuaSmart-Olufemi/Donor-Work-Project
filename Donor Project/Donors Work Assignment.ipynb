# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
from sklearn.model_selection import train_test_split

# %%
# importing libraries for data visualisations
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib
# %matplotlib inline
color = sns.color_palette()
from IPython.display import display
pd.options.display.max_columns = None

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier

# %%
# importing libraries for data handling and analysis
import pandas as pd
from pandas.plotting import scatter_matrix
from pandas import ExcelWriter
from pandas import ExcelFile
from openpyxl import load_workbook
import numpy as np
from scipy.stats import norm, skew
from scipy import stats
import statsmodels.api as sm

# %%
# importing libraries for data visualisations
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib
# %matplotlib inline
color = sns.color_palette()
from IPython.display import display
pd.options.display.max_columns = None

# %%
# sklearn modules for preprocessing
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# from imblearn.over_sampling import SMOTE  # SMOTE
# sklearn modules for ML model selection
from sklearn.model_selection import train_test_split  # import 'train_test_split'
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score


# Common sklearn Model Helpers
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics
# from sklearn.datasets import make_classification

# sklearn modules for performance metrics
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve
from sklearn.metrics import auc, roc_auc_score, roc_curve, recall_score, log_loss
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, make_scorer
from sklearn.metrics import average_precision_score

# %%
# importing misceallenous libraries
import os
import re
import sys
import timeit
import string
from datetime import datetime
from time import time
from dateutil.parser import parse
# ip = get_ipython()
# ip.register_magics(jupyternotify.JupyterNotifyMagics)

# %%
path = "C:/Users/EO/Desktop/Josh Folder/downloads/ML ASSIGNMENT/Donor Raw Data_ML with Python.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 0         0       NaN               5                  101       87.0
# 1         1      10.0              12                  137       79.0
# 2         0       NaN              37                  113       75.0
# 3         0       NaN              38                   92        NaN
# 4         0       NaN              41                  101       74.0
#
#    IN_HOUSE URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  \
# 0         0          ?   ?            .          H            M           2.0
# 1         0          R   2           45          H            M           7.0
# 2         0          S   1           11          H            F           5.0
# 3         0          U   2           04          H            F           6.0
# 4         0          R   2           49          U            F           2.0
#
#    PUBLISHED_PHONE OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  \
# 0                0              P             0            NaN
# 1                0              P             0            3.0
# 2                0              P             0            9.0
# 3                1              B             0            4.0
# 4                1              B             8            5.0
#
#    MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# 0                554                      294                  76
# 1                334                      212                  72
# 2               2388                      405                  63
# 3               1688                      153                   3
# 4                514                      328                  90
#
#    PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# 0              11855               0               0               0
# 1              10385               0              41              21
# 2              30855               0              25              26
# 3              16342               0              25              32
# 4              12107               0              33              36
#
#    PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0               0         1                   0                   A
# 1              31         1                   1                   S
# 2              57         1                   1                   S
# 3              42         1                   0                   A
# 4              37         0                   0                   A
#
#    FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                      1                 0.067                15.00
# 1                      2                 0.235                15.00
# 2                      3                 0.409                21.67
# 3                      3                 0.474                13.44
# 4                      1                 0.100                17.50
#
#    RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.000                      0.00                      1
# 1                      0.250                     15.00                      4
# 2                      0.545                     22.67                      9
# 3                      0.400                     13.50                      9
# 4                      0.111                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                         26.0
# 1                           2                         11.0
# 2                           6                         14.0
# 3                           4                         11.0
# 4                           1                         18.0
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                 297.0
# 1                  32             90                 368.0
# 2                  44            119                 603.0
# 3                  31             96                 435.0
# 4                  30             83                 106.0
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                 15.0
# 1                   25                  14.72                 20.0
# 2                   36                  16.75                 23.0
# 3                   37                  11.76                 14.0
# 4                   12                   8.83                 20.0
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                   20.0                    5.0           15.0             5
# 1                   25.0                    5.0           17.0             7
# 2                   28.0                    5.0           19.0            11
# 3                   17.0                    3.0           15.0            11
# 4                   25.0                    5.0           25.0             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3

# %%
data.describe()
# Out:
#            TARGET_B     TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  \
# count  19372.000000  4843.000000    19372.000000         19372.000000
# mean       0.250000    15.624344    96546.225377            73.409973
# std        0.433024    12.445137    55830.643871            41.255574
# min        0.000000     1.000000        5.000000             5.000000
# 25%        0.000000    10.000000    48289.000000            29.000000
# 50%        0.000000    13.000000    96937.000000            65.000000
# 75%        0.250000    20.000000   145429.500000           113.000000
# max        1.000000   200.000000   191779.000000           137.000000
#
#           DONOR_AGE      IN_HOUSE  INCOME_GROUP  PUBLISHED_PHONE  \
# count  14577.000000  19372.000000  14980.000000     19372.000000
# mean      58.919051      0.073198      3.907543         0.497729
# std       16.669382      0.260469      1.864796         0.500008
# min        0.000000      0.000000      1.000000         0.000000
# 25%       47.000000      0.000000      2.000000         0.000000
# 50%       60.000000      0.000000      4.000000         0.000000
# 75%       73.000000      0.000000      5.000000         1.000000
# max       87.000000      1.000000      7.000000         1.000000
#
#        MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# count  19372.000000   10562.000000       19372.000000
# mean       3.361656       5.005397        1079.871929
# std        9.503481       2.815386         960.753448
# min        0.000000       0.000000           0.000000
# 25%        0.000000       3.000000         518.000000
# 50%        0.000000       5.000000         747.000000
# 75%        3.000000       7.000000        1227.000000
# max      241.000000       9.000000        6000.000000
#
#        MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# count             19372.000000        19372.000000       19372.000000
# mean                341.970215           69.698999       15857.334452
# std                 164.207807           21.711019        8710.630390
# min                   0.000000            0.000000           0.000000
# 25%                 232.000000           60.000000       10869.000000
# 50%                 311.000000           76.000000       13816.500000
# 75%                 417.000000           85.000000       18308.250000
# max                1500.000000           99.000000      174523.000000
#
#        PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  \
# count    19372.000000    19372.000000    19372.000000    19372.000000
# mean         1.029011       30.573921       29.603293       32.852467
# std          4.918297       11.421471       15.120360       17.839765
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000       25.000000       20.000000       21.000000
# 50%          0.000000       31.000000       29.000000       32.000000
# 75%          0.000000       37.000000       39.000000       43.000000
# max         97.000000       99.000000       99.000000       99.000000
#
#            PEP_STAR  RECENT_STAR_STATUS  FREQUENCY_STATUS_97NK  \
# count  19372.000000        19372.000000           19372.000000
# mean       0.504439            0.931138               1.983998
# std        0.499993            2.545585               1.099346
# min        0.000000            0.000000               1.000000
# 25%        0.000000            0.000000               1.000000
# 50%        1.000000            0.000000               2.000000
# 75%        1.000000            1.000000               3.000000
# max        1.000000           22.000000               4.000000
#
#        RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# count          19372.000000         19372.000000               19372.000000
# mean               0.190127            15.365396                   0.230808
# std                0.113947            10.167485                   0.186230
# min                0.000000             0.000000                   0.000000
# 25%                0.105000            10.000000                   0.100000
# 50%                0.167000            14.000000                   0.200000
# 75%                0.250000            20.000000                   0.333000
# max                1.000000           260.000000                   1.000000
#
#        RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# count               19372.00000           19372.000000
# mean                   11.68547               3.043103
# std                    10.83412               2.046401
# min                     0.00000               0.000000
# 25%                     5.00000               2.000000
# 50%                    10.14000               3.000000
# 75%                    16.00000               4.000000
# max                   300.00000              16.000000
#
#        RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# count                19372.000000                 19126.000000
# mean                     1.730539                    19.038900
# std                      1.535521                     3.415559
# min                      0.000000                   -12.000000
# 25%                      1.000000                    17.000000
# 50%                      1.000000                    18.000000
# 75%                      2.000000                    21.000000
# max                      9.000000                    36.000000
#
#        LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# count        19372.000000   19372.000000          19372.000000
# mean            18.668078      47.570514            104.425716
# std              8.558778      22.950158            105.722460
# min              2.000000       5.000000             15.000000
# 25%             11.000000      28.000000             42.000000
# 50%             18.000000      47.000000             79.000000
# 75%             26.000000      64.000000            132.000000
# max             56.000000     194.000000           3775.000000
#
#        LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# count         19372.000000           19372.000000         19372.000000
# mean              9.979765              12.858338            11.587876
# std               8.688163               8.787758            15.116893
# min               1.000000               1.360000             0.000000
# 25%               4.000000               8.000000             5.000000
# 50%               8.000000              11.200000            10.000000
# 75%              14.000000              15.000000            15.000000
# max              95.000000             450.000000           997.000000
#
#        LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# count           19372.000000           19372.000000   19372.000000
# mean               19.208808               7.620932      16.584199
# std                16.101128               7.959786      11.977558
# min                 5.000000               0.000000       0.000000
# 25%                12.000000               3.000000      10.000000
# 50%                16.000000               5.000000      15.000000
# 75%                21.000000              10.000000      20.000000
# max              1000.000000             450.000000     450.000000
#
#        CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# count  19372.000000    19372.000000            19372.000000
# mean       5.367128       12.901869               18.191152
# std        1.264205        4.642072                4.033065
# min        0.000000        2.000000                4.000000
# 25%        5.000000       11.000000               16.000000
# 50%        6.000000       12.000000               18.000000
# 75%        6.000000       13.000000               20.000000
# max       17.000000       64.000000               27.000000
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# count             19372.000000   19372.000000    19372.000000
# mean                 69.482088      12.858338        5.273591
# std                  37.568169       8.787758        4.607063
# min                  15.000000       1.360000        0.000000
# 25%                  33.000000       8.000000        2.000000
# 50%                  65.000000      11.200000        4.000000
# 75%                 105.000000      15.000000        8.000000
# max                 260.000000     450.000000       41.000000

# %%
#The relatioship to explore is that of each attribute to the class attribute.
data.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %%
#rename TARGE_B AS Donated?
data.rename(columns={'TARGET_B':'Donated'}, inplace=True)

# %%
plt.figure(figsize=(3,6))
sns.countplot(x='Donated', data=data)
# From the data, we can see that non-donors outnumber actual donors at almost 3 to 1

# %%
data['Donated'].value_counts()
# From here we can see the amount of non-donors to donors in our dataset
# Out:
# 0    14529
# 1     4843
# Name: Donated, dtype: int64

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(6,6))
sns.countplot(x='DONOR_GENDER',
              hue='Donated',
              data=data,
             palette='Set1')
plt.show()
# This graph shows us that a significant portion of the male and females fall as non-donors

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(6,6))
sns.countplot(x='HOME_OWNER',
              hue='Donated',
              data=data,
             palette='Set1')
plt.show()
# This graph shows us that home ownership is a strong indicator tthat someone will donate

# %%
data['DONOR_AGE'].plot.hist(figsize=(10,5))
# This shows us that most of the donors fall betweeen the ages pf 40 - 80 
# This gives us valuable information o who to target based on age

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(6,6))
sns.countplot(x='INCOME_GROUP',
              hue='DONOR_GENDER',
              data=data,
             palette='Set1')
plt.show()
# This graph shows us that across all income groups,females out earn the men. They will also make for a group to target

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(6,6))
sns.countplot(x='HOME_OWNER',
              hue='DONOR_GENDER',
              data=data,
             palette='Set1')
plt.show()
# We also found out that on average females own more homes than men

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(6,6))
sns.countplot(x='URBANICITY',
              hue='Donated',
              data=data,
             palette='Set1')
plt.show()
# We found out that the people most likely to donate live in suburban areas. 
# This makes sense as most of this demographic fall between the older age brackets as seen before when we checked age of donors

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(6,6))
sns.countplot(x='SES',
              hue='Donated',
              data=data,
             palette='Set1')
plt.show()
# This shows that most of the people likely to donate fall intot he second social economic status bracket

# %%
data['LIFETIME_AVG_GIFT_AMT'].plot.hist(bins=5, figsize=(10,5))
# This metric is to show us the overall gift amount from donors. From the graph we can see the that this amount is close to a 100

# %% [markdown]
# # Imputing Missing Data

# %%
data.isnull().sum()
# Out:
# Donated                            0
# TARGET_D                       14529
# CONTROL_NUMBER                     0
# MONTHS_SINCE_ORIGIN                0
# DONOR_AGE                       4795
# IN_HOUSE                           0
# URBANICITY                         0
# SES                                0
# CLUSTER_CODE                       0
# HOME_OWNER                         0
# DONOR_GENDER                       0
# INCOME_GROUP                    4392
# PUBLISHED_PHONE                    0
# OVERLAY_SOURCE                     0
# MOR_HIT_RATE                       0
# WEALTH_RATING                   8810
# MEDIAN_HOME_VALUE                  0
# MEDIAN_HOUSEHOLD_INCOME            0
# PCT_OWNER_OCCUPIED                 0
# PER_CAPITA_INCOME                  0
# PCT_ATTRIBUTE1                     0
# PCT_ATTRIBUTE2                     0
# PCT_ATTRIBUTE3                     0
# PCT_ATTRIBUTE4                     0
# PEP_STAR                           0
# RECENT_STAR_STATUS                 0
# RECENCY_STATUS_96NK                0
# FREQUENCY_STATUS_97NK              0
# RECENT_RESPONSE_PROP               0
# RECENT_AVG_GIFT_AMT                0
# RECENT_CARD_RESPONSE_PROP          0
# RECENT_AVG_CARD_GIFT_AMT           0
# RECENT_RESPONSE_COUNT              0
# RECENT_CARD_RESPONSE_COUNT         0
# MONTHS_SINCE_LAST_PROM_RESP      246
# LIFETIME_CARD_PROM                 0
# LIFETIME_PROM                      0
# LIFETIME_GIFT_AMOUNT               0
# LIFETIME_GIFT_COUNT                0
# LIFETIME_AVG_GIFT_AMT              0
# LIFETIME_GIFT_RANGE                0
# LIFETIME_MAX_GIFT_AMT              0
# LIFETIME_MIN_GIFT_AMT              0
# LAST_GIFT_AMT                      0
# CARD_PROM_12                       0
# NUMBER_PROM_12                     0
# MONTHS_SINCE_LAST_GIFT             0
# MONTHS_SINCE_FIRST_GIFT            0
# FILE_AVG_GIFT                      0
# FILE_CARD_GIFT                     0
# dtype: int64

# %%
#the columns with missing data are
DONOR_AGE
INCOME_GROUP
WEALTH_RATING
MONTHS_SINCE_LAST_PROM_RESP

# %%
# I'm dropping these two columns as they aren't needed for the work going forward
data.drop(['TARGET_D'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    Donated  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0        0               5                  101       87.0         0
# 1        1              12                  137       79.0         0
# 2        0              37                  113       75.0         0
# 3        0              38                   92        NaN         0
# 4        0              41                  101       74.0         0
#
#   URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  \
# 0          ?   ?            .          H            M           2.0
# 1          R   2           45          H            M           7.0
# 2          S   1           11          H            F           5.0
# 3          U   2           04          H            F           6.0
# 4          R   2           49          U            F           2.0
#
#    PUBLISHED_PHONE OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  \
# 0                0              P             0            NaN
# 1                0              P             0            3.0
# 2                0              P             0            9.0
# 3                1              B             0            4.0
# 4                1              B             8            5.0
#
#    MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# 0                554                      294                  76
# 1                334                      212                  72
# 2               2388                      405                  63
# 3               1688                      153                   3
# 4                514                      328                  90
#
#    PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# 0              11855               0               0               0
# 1              10385               0              41              21
# 2              30855               0              25              26
# 3              16342               0              25              32
# 4              12107               0              33              36
#
#    PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0               0         1                   0                   A
# 1              31         1                   1                   S
# 2              57         1                   1                   S
# 3              42         1                   0                   A
# 4              37         0                   0                   A
#
#    FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                      1                 0.067                15.00
# 1                      2                 0.235                15.00
# 2                      3                 0.409                21.67
# 3                      3                 0.474                13.44
# 4                      1                 0.100                17.50
#
#    RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.000                      0.00                      1
# 1                      0.250                     15.00                      4
# 2                      0.545                     22.67                      9
# 3                      0.400                     13.50                      9
# 4                      0.111                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                         26.0
# 1                           2                         11.0
# 2                           6                         14.0
# 3                           4                         11.0
# 4                           1                         18.0
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                 297.0
# 1                  32             90                 368.0
# 2                  44            119                 603.0
# 3                  31             96                 435.0
# 4                  30             83                 106.0
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                 15.0
# 1                   25                  14.72                 20.0
# 2                   36                  16.75                 23.0
# 3                   37                  11.76                 14.0
# 4                   12                   8.83                 20.0
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                   20.0                    5.0           15.0             5
# 1                   25.0                    5.0           17.0             7
# 2                   28.0                    5.0           19.0            11
# 3                   17.0                    3.0           15.0            11
# 4                   25.0                    5.0           25.0             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3

# %%
data['DONOR_AGE'].plot.hist(figsize=(10,5))

# %% [markdown]
# - the data is left-skewed.
# - employ median to fill in missing data

# %%
# Replace using median
median = data['DONOR_AGE'].median()

# %%
data['DONOR_AGE'].fillna(median, inplace=True)

# %%
data['DONOR_AGE'].plot.hist(figsize=(10,5))

# %%
data['INCOME_GROUP'].plot.hist(figsize=(10,5))

# %% [markdown]
# - employ mode for categorical data

# %%
data['INCOME_GROUP']= data['INCOME_GROUP'].fillna(data['INCOME_GROUP'].mode().iloc[0])

# %%
data['INCOME_GROUP'].plot.hist(figsize=(10,5))

# %%
data['WEALTH_RATING'].plot.hist(figsize=(10,5))

# %% [markdown]
# - EMPLOY MEDIAN AS THE DATA IS SKEWED (TO THE LEFT)

# %%
# Replace using median
median = data['WEALTH_RATING'].median()

# %%
data['WEALTH_RATING'].fillna(median, inplace=True)

# %%
data['WEALTH_RATING'].plot.hist(figsize=(10,5))

# %%
MONTHS_SINCE_LAST_PROM_RESP

# %%
data['MONTHS_SINCE_LAST_PROM_RESP'].plot.hist(figsize=(10,5))

# %% [markdown]
# - from the distribution, we will employ to mean to fill in missing data

# %%
data['MONTHS_SINCE_LAST_PROM_RESP']= data['MONTHS_SINCE_LAST_PROM_RESP'].fillna(data['MONTHS_SINCE_LAST_PROM_RESP'].mean())

# %%
data['MONTHS_SINCE_LAST_PROM_RESP'].plot.hist(figsize=(10,5))

# %%
#check again to see if there are still any missing values
data.isnull().sum()
# Out:
# Donated                        0
# CONTROL_NUMBER                 0
# MONTHS_SINCE_ORIGIN            0
# DONOR_AGE                      0
# IN_HOUSE                       0
# URBANICITY                     0
# SES                            0
# CLUSTER_CODE                   0
# HOME_OWNER                     0
# DONOR_GENDER                   0
# INCOME_GROUP                   0
# PUBLISHED_PHONE                0
# OVERLAY_SOURCE                 0
# MOR_HIT_RATE                   0
# WEALTH_RATING                  0
# MEDIAN_HOME_VALUE              0
# MEDIAN_HOUSEHOLD_INCOME        0
# PCT_OWNER_OCCUPIED             0
# PER_CAPITA_INCOME              0
# PCT_ATTRIBUTE1                 0
# PCT_ATTRIBUTE2                 0
# PCT_ATTRIBUTE3                 0
# PCT_ATTRIBUTE4                 0
# PEP_STAR                       0
# RECENT_STAR_STATUS             0
# RECENCY_STATUS_96NK            0
# FREQUENCY_STATUS_97NK          0
# RECENT_RESPONSE_PROP           0
# RECENT_AVG_GIFT_AMT            0
# RECENT_CARD_RESPONSE_PROP      0
# RECENT_AVG_CARD_GIFT_AMT       0
# RECENT_RESPONSE_COUNT          0
# RECENT_CARD_RESPONSE_COUNT     0
# MONTHS_SINCE_LAST_PROM_RESP    0
# LIFETIME_CARD_PROM             0
# LIFETIME_PROM                  0
# LIFETIME_GIFT_AMOUNT           0
# LIFETIME_GIFT_COUNT            0
# LIFETIME_AVG_GIFT_AMT          0
# LIFETIME_GIFT_RANGE            0
# LIFETIME_MAX_GIFT_AMT          0
# LIFETIME_MIN_GIFT_AMT          0
# LAST_GIFT_AMT                  0
# CARD_PROM_12                   0
# NUMBER_PROM_12                 0
# MONTHS_SINCE_LAST_GIFT         0
# MONTHS_SINCE_FIRST_GIFT        0
# FILE_AVG_GIFT                  0
# FILE_CARD_GIFT                 0
# dtype: int64

# %% [markdown]
# # It is important to check for the data types in your dataset

# %% [markdown]
# - if the data type is that ofan object or a timestamp for example, it will affect your code when you want to run models

# %%
data.dtypes
# Out:
# Donated                          int64
# CONTROL_NUMBER                   int64
# MONTHS_SINCE_ORIGIN              int64
# DONOR_AGE                      float64
# IN_HOUSE                         int64
# URBANICITY                      object
# SES                             object
# CLUSTER_CODE                    object
# HOME_OWNER                      object
# DONOR_GENDER                    object
# INCOME_GROUP                   float64
# PUBLISHED_PHONE                  int64
# OVERLAY_SOURCE                  object
# MOR_HIT_RATE                     int64
# WEALTH_RATING                  float64
# MEDIAN_HOME_VALUE                int64
# MEDIAN_HOUSEHOLD_INCOME          int64
# PCT_OWNER_OCCUPIED               int64
# PER_CAPITA_INCOME                int64
# PCT_ATTRIBUTE1                   int64
# PCT_ATTRIBUTE2                   int64
# PCT_ATTRIBUTE3                   int64
# PCT_ATTRIBUTE4                   int64
# PEP_STAR                         int64
# RECENT_STAR_STATUS               int64
# RECENCY_STATUS_96NK             object
# FREQUENCY_STATUS_97NK            int64
# RECENT_RESPONSE_PROP           float64
# RECENT_AVG_GIFT_AMT            float64
# RECENT_CARD_RESPONSE_PROP      float64
# RECENT_AVG_CARD_GIFT_AMT       float64
# RECENT_RESPONSE_COUNT            int64
# RECENT_CARD_RESPONSE_COUNT       int64
# MONTHS_SINCE_LAST_PROM_RESP    float64
# LIFETIME_CARD_PROM               int64
# LIFETIME_PROM                    int64
# LIFETIME_GIFT_AMOUNT           float64
# LIFETIME_GIFT_COUNT              int64
# LIFETIME_AVG_GIFT_AMT          float64
# LIFETIME_GIFT_RANGE            float64
# LIFETIME_MAX_GIFT_AMT          float64
# LIFETIME_MIN_GIFT_AMT          float64
# LAST_GIFT_AMT                  float64
# CARD_PROM_12                     int64
# NUMBER_PROM_12                   int64
# MONTHS_SINCE_LAST_GIFT           int64
# MONTHS_SINCE_FIRST_GIFT          int64
# FILE_AVG_GIFT                  float64
# FILE_CARD_GIFT                   int64
# dtype: object

# %% [markdown]
# # Dealing with miscellaneous data

# %% [markdown]
# #### Despite the fact that there are no "missing" values, there are some misellaneous values in the data set like '?' and   ' .'
# #### We will deal with them now

# %%
data.head()
# Out:
#    Donated  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0        0               5                  101       87.0         0
# 1        1              12                  137       79.0         0
# 2        0              37                  113       75.0         0
# 3        0              38                   92       60.0         0
# 4        0              41                  101       74.0         0
#
#   URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  \
# 0          ?   ?            .          H            M           2.0
# 1          R   2           45          H            M           7.0
# 2          S   1           11          H            F           5.0
# 3          U   2           04          H            F           6.0
# 4          R   2           49          U            F           2.0
#
#    PUBLISHED_PHONE OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  \
# 0                0              P             0            5.0
# 1                0              P             0            3.0
# 2                0              P             0            9.0
# 3                1              B             0            4.0
# 4                1              B             8            5.0
#
#    MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# 0                554                      294                  76
# 1                334                      212                  72
# 2               2388                      405                  63
# 3               1688                      153                   3
# 4                514                      328                  90
#
#    PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# 0              11855               0               0               0
# 1              10385               0              41              21
# 2              30855               0              25              26
# 3              16342               0              25              32
# 4              12107               0              33              36
#
#    PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0               0         1                   0                   A
# 1              31         1                   1                   S
# 2              57         1                   1                   S
# 3              42         1                   0                   A
# 4              37         0                   0                   A
#
#    FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                      1                 0.067                15.00
# 1                      2                 0.235                15.00
# 2                      3                 0.409                21.67
# 3                      3                 0.474                13.44
# 4                      1                 0.100                17.50
#
#    RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.000                      0.00                      1
# 1                      0.250                     15.00                      4
# 2                      0.545                     22.67                      9
# 3                      0.400                     13.50                      9
# 4                      0.111                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                         26.0
# 1                           2                         11.0
# 2                           6                         14.0
# 3                           4                         11.0
# 4                           1                         18.0
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                 297.0
# 1                  32             90                 368.0
# 2                  44            119                 603.0
# 3                  31             96                 435.0
# 4                  30             83                 106.0
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                 15.0
# 1                   25                  14.72                 20.0
# 2                   36                  16.75                 23.0
# 3                   37                  11.76                 14.0
# 4                   12                   8.83                 20.0
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                   20.0                    5.0           15.0             5
# 1                   25.0                    5.0           17.0             7
# 2                   28.0                    5.0           19.0            11
# 3                   17.0                    3.0           15.0            11
# 4                   25.0                    5.0           25.0             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3

# %% [markdown]
# ### SES, URBANICITY and CLUSTER_CODE seem to all have miscellaneous data

# %%
data = data.replace("?",np.nan)

# %%
data['CLUSTER_CODE'] = data.CLUSTER_CODE.replace(' .',0)

# %%
#CHECK DATA TO SEE IF COLUMNS ARE CLEANED
data.head()
# Out:
#    Donated  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0        0               5                  101       87.0         0
# 1        1              12                  137       79.0         0
# 2        0              37                  113       75.0         0
# 3        0              38                   92       60.0         0
# 4        0              41                  101       74.0         0
#
#   URBANICITY  SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  \
# 0        NaN  NaN            0          H            M           2.0
# 1          R    2           45          H            M           7.0
# 2          S    1           11          H            F           5.0
# 3          U    2           04          H            F           6.0
# 4          R    2           49          U            F           2.0
#
#    PUBLISHED_PHONE OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  \
# 0                0              P             0            5.0
# 1                0              P             0            3.0
# 2                0              P             0            9.0
# 3                1              B             0            4.0
# 4                1              B             8            5.0
#
#    MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# 0                554                      294                  76
# 1                334                      212                  72
# 2               2388                      405                  63
# 3               1688                      153                   3
# 4                514                      328                  90
#
#    PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# 0              11855               0               0               0
# 1              10385               0              41              21
# 2              30855               0              25              26
# 3              16342               0              25              32
# 4              12107               0              33              36
#
#    PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0               0         1                   0                   A
# 1              31         1                   1                   S
# 2              57         1                   1                   S
# 3              42         1                   0                   A
# 4              37         0                   0                   A
#
#    FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                      1                 0.067                15.00
# 1                      2                 0.235                15.00
# 2                      3                 0.409                21.67
# 3                      3                 0.474                13.44
# 4                      1                 0.100                17.50
#
#    RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.000                      0.00                      1
# 1                      0.250                     15.00                      4
# 2                      0.545                     22.67                      9
# 3                      0.400                     13.50                      9
# 4                      0.111                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                         26.0
# 1                           2                         11.0
# 2                           6                         14.0
# 3                           4                         11.0
# 4                           1                         18.0
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                 297.0
# 1                  32             90                 368.0
# 2                  44            119                 603.0
# 3                  31             96                 435.0
# 4                  30             83                 106.0
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                 15.0
# 1                   25                  14.72                 20.0
# 2                   36                  16.75                 23.0
# 3                   37                  11.76                 14.0
# 4                   12                   8.83                 20.0
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                   20.0                    5.0           15.0             5
# 1                   25.0                    5.0           17.0             7
# 2                   28.0                    5.0           19.0            11
# 3                   17.0                    3.0           15.0            11
# 4                   25.0                    5.0           25.0             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3

# %%
data.isnull().sum()
# Out:
# Donated                          0
# CONTROL_NUMBER                   0
# MONTHS_SINCE_ORIGIN              0
# DONOR_AGE                        0
# IN_HOUSE                         0
# URBANICITY                     454
# SES                            454
# CLUSTER_CODE                     0
# HOME_OWNER                       0
# DONOR_GENDER                     0
# INCOME_GROUP                     0
# PUBLISHED_PHONE                  0
# OVERLAY_SOURCE                   0
# MOR_HIT_RATE                     0
# WEALTH_RATING                    0
# MEDIAN_HOME_VALUE                0
# MEDIAN_HOUSEHOLD_INCOME          0
# PCT_OWNER_OCCUPIED               0
# PER_CAPITA_INCOME                0
# PCT_ATTRIBUTE1                   0
# PCT_ATTRIBUTE2                   0
# PCT_ATTRIBUTE3                   0
# PCT_ATTRIBUTE4                   0
# PEP_STAR                         0
# RECENT_STAR_STATUS               0
# RECENCY_STATUS_96NK              0
# FREQUENCY_STATUS_97NK            0
# RECENT_RESPONSE_PROP             0
# RECENT_AVG_GIFT_AMT              0
# RECENT_CARD_RESPONSE_PROP        0
# RECENT_AVG_CARD_GIFT_AMT         0
# RECENT_RESPONSE_COUNT            0
# RECENT_CARD_RESPONSE_COUNT       0
# MONTHS_SINCE_LAST_PROM_RESP      0
# LIFETIME_CARD_PROM               0
# LIFETIME_PROM                    0
# LIFETIME_GIFT_AMOUNT             0
# LIFETIME_GIFT_COUNT              0
# LIFETIME_AVG_GIFT_AMT            0
# LIFETIME_GIFT_RANGE              0
# LIFETIME_MAX_GIFT_AMT            0
# LIFETIME_MIN_GIFT_AMT            0
# LAST_GIFT_AMT                    0
# CARD_PROM_12                     0
# NUMBER_PROM_12                   0
# MONTHS_SINCE_LAST_GIFT           0
# MONTHS_SINCE_FIRST_GIFT          0
# FILE_AVG_GIFT                    0
# FILE_CARD_GIFT                   0
# dtype: int64

# %% [markdown]
# - data seems to be cleaned for SES and URBANICITY column but not CLUSTER_CODE column.
# - Let's deal with the first two column first

# %% [markdown]
# - we can't plot to see the distribution of urbanicity because it is categorical data

# %%
#we wil handle the missing data using mode
data['URBANICITY']= data['URBANICITY'].fillna(data['URBANICITY'].mode().iloc[0])
data['SES']= data['SES'].fillna(data['SES'].mode().iloc[0])

# %%
data.dtypes
# Out:
# Donated                          int64
# CONTROL_NUMBER                   int64
# MONTHS_SINCE_ORIGIN              int64
# DONOR_AGE                      float64
# IN_HOUSE                         int64
# URBANICITY                      object
# SES                             object
# CLUSTER_CODE                    object
# HOME_OWNER                      object
# DONOR_GENDER                    object
# INCOME_GROUP                   float64
# PUBLISHED_PHONE                  int64
# OVERLAY_SOURCE                  object
# MOR_HIT_RATE                     int64
# WEALTH_RATING                  float64
# MEDIAN_HOME_VALUE                int64
# MEDIAN_HOUSEHOLD_INCOME          int64
# PCT_OWNER_OCCUPIED               int64
# PER_CAPITA_INCOME                int64
# PCT_ATTRIBUTE1                   int64
# PCT_ATTRIBUTE2                   int64
# PCT_ATTRIBUTE3                   int64
# PCT_ATTRIBUTE4                   int64
# PEP_STAR                         int64
# RECENT_STAR_STATUS               int64
# RECENCY_STATUS_96NK             object
# FREQUENCY_STATUS_97NK            int64
# RECENT_RESPONSE_PROP           float64
# RECENT_AVG_GIFT_AMT            float64
# RECENT_CARD_RESPONSE_PROP      float64
# RECENT_AVG_CARD_GIFT_AMT       float64
# RECENT_RESPONSE_COUNT            int64
# RECENT_CARD_RESPONSE_COUNT       int64
# MONTHS_SINCE_LAST_PROM_RESP    float64
# LIFETIME_CARD_PROM               int64
# LIFETIME_PROM                    int64
# LIFETIME_GIFT_AMOUNT           float64
# LIFETIME_GIFT_COUNT              int64
# LIFETIME_AVG_GIFT_AMT          float64
# LIFETIME_GIFT_RANGE            float64
# LIFETIME_MAX_GIFT_AMT          float64
# LIFETIME_MIN_GIFT_AMT          float64
# LAST_GIFT_AMT                  float64
# CARD_PROM_12                     int64
# NUMBER_PROM_12                   int64
# MONTHS_SINCE_LAST_GIFT           int64
# MONTHS_SINCE_FIRST_GIFT          int64
# FILE_AVG_GIFT                  float64
# FILE_CARD_GIFT                   int64
# dtype: object

# %%
data.head()
# Out:
#    Donated  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0        0               5                  101       87.0         0
# 1        1              12                  137       79.0         0
# 2        0              37                  113       75.0         0
# 3        0              38                   92       60.0         0
# 4        0              41                  101       74.0         0
#
#   URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  \
# 0          S   2            0          H            M           2.0
# 1          R   2           45          H            M           7.0
# 2          S   1           11          H            F           5.0
# 3          U   2           04          H            F           6.0
# 4          R   2           49          U            F           2.0
#
#    PUBLISHED_PHONE OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  \
# 0                0              P             0            5.0
# 1                0              P             0            3.0
# 2                0              P             0            9.0
# 3                1              B             0            4.0
# 4                1              B             8            5.0
#
#    MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# 0                554                      294                  76
# 1                334                      212                  72
# 2               2388                      405                  63
# 3               1688                      153                   3
# 4                514                      328                  90
#
#    PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# 0              11855               0               0               0
# 1              10385               0              41              21
# 2              30855               0              25              26
# 3              16342               0              25              32
# 4              12107               0              33              36
#
#    PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0               0         1                   0                   A
# 1              31         1                   1                   S
# 2              57         1                   1                   S
# 3              42         1                   0                   A
# 4              37         0                   0                   A
#
#    FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                      1                 0.067                15.00
# 1                      2                 0.235                15.00
# 2                      3                 0.409                21.67
# 3                      3                 0.474                13.44
# 4                      1                 0.100                17.50
#
#    RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.000                      0.00                      1
# 1                      0.250                     15.00                      4
# 2                      0.545                     22.67                      9
# 3                      0.400                     13.50                      9
# 4                      0.111                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                         26.0
# 1                           2                         11.0
# 2                           6                         14.0
# 3                           4                         11.0
# 4                           1                         18.0
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                 297.0
# 1                  32             90                 368.0
# 2                  44            119                 603.0
# 3                  31             96                 435.0
# 4                  30             83                 106.0
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                 15.0
# 1                   25                  14.72                 20.0
# 2                   36                  16.75                 23.0
# 3                   37                  11.76                 14.0
# 4                   12                   8.83                 20.0
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                   20.0                    5.0           15.0             5
# 1                   25.0                    5.0           17.0             7
# 2                   28.0                    5.0           19.0            11
# 3                   17.0                    3.0           15.0            11
# 4                   25.0                    5.0           25.0             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3

# %% [markdown]
# - so we use label encoding to handle categorical data

# %% [markdown]
# # Handling Categorical Data

# %%
# start with URBANICITY. 
data['URBANICITY'] = data['URBANICITY'].astype('category')
#I change the data type to category so I can use cat.codes on the URBANICITY column

# %%
data['URBANICITY'] = data['URBANICITY'].cat.codes
# here I use label encoding to handle the categorical data that is the column URBANICITY

# %%
#DO THE SAME FOR OVERLAY_SOURCE
data['OVERLAY_SOURCE'] = data['OVERLAY_SOURCE'].astype('category')
data['OVERLAY_SOURCE'] = data['OVERLAY_SOURCE'].cat.codes

# %%
data.head()
# Out:
#    Donated  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0        0               5                  101       87.0         0
# 1        1              12                  137       79.0         0
# 2        0              37                  113       75.0         0
# 3        0              38                   92       60.0         0
# 4        0              41                  101       74.0         0
#
#    URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  \
# 0           2   2            0          H            M           2.0
# 1           1   2           45          H            M           7.0
# 2           2   1           11          H            F           5.0
# 3           4   2           04          H            F           6.0
# 4           1   2           49          U            F           2.0
#
#    PUBLISHED_PHONE  OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  \
# 0                0               3             0            5.0
# 1                0               3             0            3.0
# 2                0               3             0            9.0
# 3                1               0             0            4.0
# 4                1               0             8            5.0
#
#    MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# 0                554                      294                  76
# 1                334                      212                  72
# 2               2388                      405                  63
# 3               1688                      153                   3
# 4                514                      328                  90
#
#    PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# 0              11855               0               0               0
# 1              10385               0              41              21
# 2              30855               0              25              26
# 3              16342               0              25              32
# 4              12107               0              33              36
#
#    PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0               0         1                   0                   A
# 1              31         1                   1                   S
# 2              57         1                   1                   S
# 3              42         1                   0                   A
# 4              37         0                   0                   A
#
#    FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                      1                 0.067                15.00
# 1                      2                 0.235                15.00
# 2                      3                 0.409                21.67
# 3                      3                 0.474                13.44
# 4                      1                 0.100                17.50
#
#    RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.000                      0.00                      1
# 1                      0.250                     15.00                      4
# 2                      0.545                     22.67                      9
# 3                      0.400                     13.50                      9
# 4                      0.111                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                         26.0
# 1                           2                         11.0
# 2                           6                         14.0
# 3                           4                         11.0
# 4                           1                         18.0
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                 297.0
# 1                  32             90                 368.0
# 2                  44            119                 603.0
# 3                  31             96                 435.0
# 4                  30             83                 106.0
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                 15.0
# 1                   25                  14.72                 20.0
# 2                   36                  16.75                 23.0
# 3                   37                  11.76                 14.0
# 4                   12                   8.83                 20.0
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                   20.0                    5.0           15.0             5
# 1                   25.0                    5.0           17.0             7
# 2                   28.0                    5.0           19.0            11
# 3                   17.0                    3.0           15.0            11
# 4                   25.0                    5.0           25.0             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3

# %%
#DO THE SAME FOR HOME_OWNER
data['HOME_OWNER'] = data['HOME_OWNER'].astype('category')
data['HOME_OWNER'] = data['HOME_OWNER'].cat.codes

# %%
#DO FOR RECENECY_STATUS_96NK
data['RECENCY_STATUS_96NK'] = data['RECENCY_STATUS_96NK'].astype('category')
data['RECENCY_STATUS_96NK'] = data['RECENCY_STATUS_96NK'].cat.codes

# %% [markdown]
# - Even though age is categorical we will not use label encoding but one-hot encoding for it.

# %%
data = pd.get_dummies(data, columns=['DONOR_GENDER'], prefix = ['DONOR_GENDER'])

# %%
data.drop(['DONOR_GENDER_A','DONOR_GENDER_U'],axis=1, inplace=True)

# %%
data.head()
# Out:
#    Donated  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0        0               5                  101       87.0         0
# 1        1              12                  137       79.0         0
# 2        0              37                  113       75.0         0
# 3        0              38                   92       60.0         0
# 4        0              41                  101       74.0         0
#
#    URBANICITY SES CLUSTER_CODE  HOME_OWNER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           2   2            0           0           2.0                0
# 1           1   2           45           0           7.0                0
# 2           2   1           11           0           5.0                0
# 3           4   2           04           0           6.0                1
# 4           1   2           49           1           2.0                1
#
#    OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0               3             0            5.0                554
# 1               3             0            3.0                334
# 2               3             0            9.0               2388
# 3               0             0            4.0               1688
# 4               0             8            5.0                514
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      294                  76              11855
# 1                      212                  72              10385
# 2                      405                  63              30855
# 3                      153                   3              16342
# 4                      328                  90              12107
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0               0               0               0         1
# 1               0              41              21              31         1
# 2               0              25              26              57         1
# 3               0              25              32              42         1
# 4               0              33              36              37         0
#
#    RECENT_STAR_STATUS  RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                    0                      1
# 1                   1                    5                      2
# 2                   1                    5                      3
# 3                   0                    0                      3
# 4                   0                    0                      1
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                 0.067                15.00                      0.000
# 1                 0.235                15.00                      0.250
# 2                 0.409                21.67                      0.545
# 3                 0.474                13.44                      0.400
# 4                 0.100                17.50                      0.111
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     15.00                      4
# 2                     22.67                      9
# 3                     13.50                      9
# 4                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                         26.0
# 1                           2                         11.0
# 2                           6                         14.0
# 3                           4                         11.0
# 4                           1                         18.0
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                 297.0
# 1                  32             90                 368.0
# 2                  44            119                 603.0
# 3                  31             96                 435.0
# 4                  30             83                 106.0
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                 15.0
# 1                   25                  14.72                 20.0
# 2                   36                  16.75                 23.0
# 3                   37                  11.76                 14.0
# 4                   12                   8.83                 20.0
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                   20.0                    5.0           15.0             5
# 1                   25.0                    5.0           17.0             7
# 2                   28.0                    5.0           19.0            11
# 3                   17.0                    3.0           15.0            11
# 4                   25.0                    5.0           25.0             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT  DONOR_GENDER_F  DONOR_GENDER_M
# 0           8.49               7               0               1
# 1          14.72              12               0               1
# 2          16.75              16               1               0
# 3          11.76              12               1               0
# 4           8.83               3               1               0

# %%
data.dtypes
#data['CLUSTER_CODE']=data.CLUSTER_CODE.replace(' .',0)
# Out:
# Donated                          int64
# CONTROL_NUMBER                   int64
# MONTHS_SINCE_ORIGIN              int64
# DONOR_AGE                      float64
# IN_HOUSE                         int64
# URBANICITY                        int8
# SES                             object
# CLUSTER_CODE                    object
# HOME_OWNER                        int8
# INCOME_GROUP                   float64
# PUBLISHED_PHONE                  int64
# OVERLAY_SOURCE                    int8
# MOR_HIT_RATE                     int64
# WEALTH_RATING                  float64
# MEDIAN_HOME_VALUE                int64
# MEDIAN_HOUSEHOLD_INCOME          int64
# PCT_OWNER_OCCUPIED               int64
# PER_CAPITA_INCOME                int64
# PCT_ATTRIBUTE1                   int64
# PCT_ATTRIBUTE2                   int64
# PCT_ATTRIBUTE3                   int64
# PCT_ATTRIBUTE4                   int64
# PEP_STAR                         int64
# RECENT_STAR_STATUS               int64
# RECENCY_STATUS_96NK               int8
# FREQUENCY_STATUS_97NK            int64
# RECENT_RESPONSE_PROP           float64
# RECENT_AVG_GIFT_AMT            float64
# RECENT_CARD_RESPONSE_PROP      float64
# RECENT_AVG_CARD_GIFT_AMT       float64
# RECENT_RESPONSE_COUNT            int64
# RECENT_CARD_RESPONSE_COUNT       int64
# MONTHS_SINCE_LAST_PROM_RESP    float64
# LIFETIME_CARD_PROM               int64
# LIFETIME_PROM                    int64
# LIFETIME_GIFT_AMOUNT           float64
# LIFETIME_GIFT_COUNT              int64
# LIFETIME_AVG_GIFT_AMT          float64
# LIFETIME_GIFT_RANGE            float64
# LIFETIME_MAX_GIFT_AMT          float64
# LIFETIME_MIN_GIFT_AMT          float64
# LAST_GIFT_AMT                  float64
# CARD_PROM_12                     int64
# NUMBER_PROM_12                   int64
# MONTHS_SINCE_LAST_GIFT           int64
# MONTHS_SINCE_FIRST_GIFT          int64
# FILE_AVG_GIFT                  float64
# FILE_CARD_GIFT                   int64
# DONOR_GENDER_F                   uint8
# DONOR_GENDER_M                   uint8
# dtype: object

# %%
data['CLUSTER_CODE']= data['CLUSTER_CODE'].fillna(data['CLUSTER_CODE'].mode().iloc[0])

# %%
# change the CLUSTER_CODE data format to numeric before feature selection
data['CLUSTER_CODE'] = pd.to_numeric(data['CLUSTER_CODE'], errors='coerce')

# %%
data.isnull().sum()
# Out:
# Donated                        0
# CONTROL_NUMBER                 0
# MONTHS_SINCE_ORIGIN            0
# DONOR_AGE                      0
# IN_HOUSE                       0
# URBANICITY                     0
# SES                            0
# CLUSTER_CODE                   0
# HOME_OWNER                     0
# INCOME_GROUP                   0
# PUBLISHED_PHONE                0
# OVERLAY_SOURCE                 0
# MOR_HIT_RATE                   0
# WEALTH_RATING                  0
# MEDIAN_HOME_VALUE              0
# MEDIAN_HOUSEHOLD_INCOME        0
# PCT_OWNER_OCCUPIED             0
# PER_CAPITA_INCOME              0
# PCT_ATTRIBUTE1                 0
# PCT_ATTRIBUTE2                 0
# PCT_ATTRIBUTE3                 0
# PCT_ATTRIBUTE4                 0
# PEP_STAR                       0
# RECENT_STAR_STATUS             0
# RECENCY_STATUS_96NK            0
# FREQUENCY_STATUS_97NK          0
# RECENT_RESPONSE_PROP           0
# RECENT_AVG_GIFT_AMT            0
# RECENT_CARD_RESPONSE_PROP      0
# RECENT_AVG_CARD_GIFT_AMT       0
# RECENT_RESPONSE_COUNT          0
# RECENT_CARD_RESPONSE_COUNT     0
# MONTHS_SINCE_LAST_PROM_RESP    0
# LIFETIME_CARD_PROM             0
# LIFETIME_PROM                  0
# LIFETIME_GIFT_AMOUNT           0
# LIFETIME_GIFT_COUNT            0
# LIFETIME_AVG_GIFT_AMT          0
# LIFETIME_GIFT_RANGE            0
# LIFETIME_MAX_GIFT_AMT          0
# LIFETIME_MIN_GIFT_AMT          0
# LAST_GIFT_AMT                  0
# CARD_PROM_12                   0
# NUMBER_PROM_12                 0
# MONTHS_SINCE_LAST_GIFT         0
# MONTHS_SINCE_FIRST_GIFT        0
# FILE_AVG_GIFT                  0
# FILE_CARD_GIFT                 0
# DONOR_GENDER_F                 0
# DONOR_GENDER_M                 0
# dtype: int64

# %% [markdown]
# # Feature Selection

# %%
# Data transformation
# Convert categorical values to numeric using label encoder
from sklearn import preprocessing
from collections import defaultdict
d = defaultdict(preprocessing.LabelEncoder)

# Encoding the categorical variable
fit = data.select_dtypes(include=['object']).fillna('NA').apply(lambda x: d[x.name].fit_transform(x))

#Convert the categorical columns based on encoding
for i in list(d.keys()):
    data[i] = d[i].transform(data[i].fillna('NA'))

# %%
features = data[data.columns.difference(['Donated'])]
labels = data['Donated']

# %%
features = features.fillna(0)

# %% [markdown]
# ## Variable Selection

# %% [markdown]
# ### Weight of Evidence and Information Value

# %%
# import packages
import pandas as pd
import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
final_iv, IV = data_vars(data[data.columns.difference(['Donated'])],data.Donated)

# %%
IV = IV.rename(columns={'VAR_NAME':'index'})
IV.sort_values(['IV'],ascending=0)
# Out:
#                           index        IV
# 43        RECENT_RESPONSE_COUNT  0.090920
# 8         FREQUENCY_STATUS_97NK  0.077015
# 41   RECENT_CARD_RESPONSE_COUNT  0.076266
# 44         RECENT_RESPONSE_PROP  0.075305
# 6                 FILE_AVG_GIFT  0.068246
# 13        LIFETIME_AVG_GIFT_AMT  0.068246
# 12                LAST_GIFT_AMT  0.066563
# 7                FILE_CARD_GIFT  0.066285
# 16          LIFETIME_GIFT_COUNT  0.064998
# 40          RECENT_AVG_GIFT_AMT  0.062091
# 18        LIFETIME_MAX_GIFT_AMT  0.059889
# 35                     PEP_STAR  0.059825
# 42    RECENT_CARD_RESPONSE_PROP  0.051517
# 19        LIFETIME_MIN_GIFT_AMT  0.045360
# 24       MONTHS_SINCE_LAST_GIFT  0.032209
# 20                LIFETIME_PROM  0.025228
# 14           LIFETIME_CARD_PROM  0.023475
# 25  MONTHS_SINCE_LAST_PROM_RESP  0.022977
# 23      MONTHS_SINCE_FIRST_GIFT  0.022408
# 26          MONTHS_SINCE_ORIGIN  0.020889
# 15         LIFETIME_GIFT_AMOUNT  0.018915
# 0                  CARD_PROM_12  0.017802
# 21            MEDIAN_HOME_VALUE  0.016123
# 28               NUMBER_PROM_12  0.015472
# 17          LIFETIME_GIFT_RANGE  0.010119
# 36            PER_CAPITA_INCOME  0.009843
# 11                     IN_HOUSE  0.008373
# 38          RECENCY_STATUS_96NK  0.008323
# 46                          SES  0.008009
# 22      MEDIAN_HOUSEHOLD_INCOME  0.007590
# 48                WEALTH_RATING  0.007577
# 39     RECENT_AVG_CARD_GIFT_AMT  0.006760
# 3                     DONOR_AGE  0.003970
# 10                 INCOME_GROUP  0.003859
# 2                CONTROL_NUMBER  0.002595
# 27                 MOR_HIT_RATE  0.002373
# 1                  CLUSTER_CODE  0.002201
# 31               PCT_ATTRIBUTE2  0.001529
# 45           RECENT_STAR_STATUS  0.001104
# 9                    HOME_OWNER  0.000978
# 29               OVERLAY_SOURCE  0.000921
# 34           PCT_OWNER_OCCUPIED  0.000497
# 32               PCT_ATTRIBUTE3  0.000285
# 5                DONOR_GENDER_M  0.000216
# 33               PCT_ATTRIBUTE4  0.000178
# 47                   URBANICITY  0.000099
# 37              PUBLISHED_PHONE  0.000055
# 4                DONOR_GENDER_F  0.000023
# 30               PCT_ATTRIBUTE1  0.000014

# %% [markdown]
# ### Apply WOE values to your dataframe columns

# %% [markdown]
# The below code snippet can be used to apply the WOE values to your dataframe columns.

# %%
transform_vars_list = data.columns.difference(['Donated'])
transform_prefix = 'new_' # leave this value blank if you need replace the original column values

# %%
transform_vars_list
# Out:
# Index(['CARD_PROM_12', 'CLUSTER_CODE', 'CONTROL_NUMBER', 'DONOR_AGE',
#        'DONOR_GENDER_F', 'DONOR_GENDER_M', 'FILE_AVG_GIFT', 'FILE_CARD_GIFT',
#        'FREQUENCY_STATUS_97NK', 'HOME_OWNER', 'INCOME_GROUP', 'IN_HOUSE',
#        'LAST_GIFT_AMT', 'LIFETIME_AVG_GIFT_AMT', 'LIFETIME_CARD_PROM',
#        'LIFETIME_GIFT_AMOUNT', 'LIFETIME_GIFT_COUNT', 'LIFETIME_GIFT_RANGE',
#        'LIFETIME_MAX_GIFT_AMT', 'LIFETIME_MIN_GIFT_AMT', 'LIFETIME_PROM',
#        'MEDIAN_HOME_VALUE', 'MEDIAN_HOUSEHOLD_INCOME',
#        'MONTHS_SINCE_FIRST_GIFT', 'MONTHS_SINCE_LAST_GIFT',
#        'MONTHS_SINCE_LAST_PROM_RESP', 'MONTHS_SINCE_ORIGIN', 'MOR_HIT_RATE',
#        'NUMBER_PROM_12', 'OVERLAY_SOURCE', 'PCT_ATTRIBUTE1', 'PCT_ATTRIBUTE2',
#        'PCT_ATTRIBUTE3', 'PCT_ATTRIBUTE4', 'PCT_OWNER_OCCUPIED', 'PEP_STAR',
#        'PER_CAPITA_INCOME', 'PUBLISHED_PHONE', 'RECENCY_STATUS_96NK',
#        'RECENT_AVG_CARD_GIFT_AMT', 'RECENT_AVG_GIFT_AMT',
#        'RECENT_CARD_RESPONSE_COUNT', 'RECENT_CARD_RESPONSE_PROP',
#        'RECENT_RESPONSE_COUNT', 'RECENT_RESPONSE_PROP', 'RECENT_STAR_STATUS',
#        'SES', 'URBANICITY', 'WEALTH_RATING'],
#       dtype='object')

# %%
for var in transform_vars_list:
    small_data = final_iv[final_iv['VAR_NAME'] == var]
    transform_dict = dict(zip(small_data.MAX_VALUE,small_data.WOE))
    replace_cmd = ''
    replace_cmd1 = ''
    for i in sorted(transform_dict.items()):
        replace_cmd = replace_cmd + str(i[1]) + str(' if x <= ') + str(i[0]) + ' else '
        replace_cmd1 = replace_cmd1 + str(i[1]) + str(' if x == "') + str(i[0]) + '" else '
    replace_cmd = replace_cmd + '0'
    replace_cmd1 = replace_cmd1 + '0'
    if replace_cmd != '0':
        try:
            data[transform_prefix + var] = data[var].apply(lambda x: eval(replace_cmd))
        except:
            data[transform_prefix + var] = data[var].apply(lambda x: eval(replace_cmd1))

# %% [markdown]
# ### Variable Importance

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

clf.fit(features,labels)

preds = clf.predict(features)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(preds,labels)
print(accuracy)
# Out:
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9765124922568655

# %%
from pandas import DataFrame
VI = DataFrame(clf.feature_importances_, columns = ["RF"], index=features.columns)

# %%
VI = VI.reset_index()
VI.sort_values(['RF'],ascending=0)
# Out:
#                           index        RF
# 2                CONTROL_NUMBER  0.042895
# 22      MEDIAN_HOUSEHOLD_INCOME  0.041947
# 21            MEDIAN_HOME_VALUE  0.040749
# 36            PER_CAPITA_INCOME  0.040058
# 34           PCT_OWNER_OCCUPIED  0.036511
# 33               PCT_ATTRIBUTE4  0.035668
# 31               PCT_ATTRIBUTE2  0.033332
# 32               PCT_ATTRIBUTE3  0.033280
# 3                     DONOR_AGE  0.032824
# 1                  CLUSTER_CODE  0.031091
# 6                 FILE_AVG_GIFT  0.030476
# 13        LIFETIME_AVG_GIFT_AMT  0.030437
# 23      MONTHS_SINCE_FIRST_GIFT  0.029389
# 40          RECENT_AVG_GIFT_AMT  0.028323
# 15         LIFETIME_GIFT_AMOUNT  0.027912
# 20                LIFETIME_PROM  0.027843
# 44         RECENT_RESPONSE_PROP  0.027769
# 14           LIFETIME_CARD_PROM  0.023703
# 42    RECENT_CARD_RESPONSE_PROP  0.022532
# 39     RECENT_AVG_CARD_GIFT_AMT  0.022077
# 25  MONTHS_SINCE_LAST_PROM_RESP  0.021241
# 24       MONTHS_SINCE_LAST_GIFT  0.020520
# 12                LAST_GIFT_AMT  0.020463
# 17          LIFETIME_GIFT_RANGE  0.020079
# 7                FILE_CARD_GIFT  0.019728
# 28               NUMBER_PROM_12  0.019584
# 16          LIFETIME_GIFT_COUNT  0.019534
# 27                 MOR_HIT_RATE  0.018440
# 10                 INCOME_GROUP  0.017348
# 18        LIFETIME_MAX_GIFT_AMT  0.016482
# 8         FREQUENCY_STATUS_97NK  0.013949
# 48                WEALTH_RATING  0.013943
# 43        RECENT_RESPONSE_COUNT  0.013513
# 19        LIFETIME_MIN_GIFT_AMT  0.012814
# 26          MONTHS_SINCE_ORIGIN  0.012800
# 0                  CARD_PROM_12  0.011263
# 30               PCT_ATTRIBUTE1  0.011079
# 47                   URBANICITY  0.010937
# 41   RECENT_CARD_RESPONSE_COUNT  0.009620
# 29               OVERLAY_SOURCE  0.009572
# 46                          SES  0.009240
# 45           RECENT_STAR_STATUS  0.006739
# 37              PUBLISHED_PHONE  0.005762
# 35                     PEP_STAR  0.004995
# 9                    HOME_OWNER  0.004989
# 5                DONOR_GENDER_M  0.004857
# 38          RECENCY_STATUS_96NK  0.004843
# 4                DONOR_GENDER_F  0.004817
# 11                     IN_HOUSE  0.002031

# %% [markdown]
# ### Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
rfe = RFE(model, 20)
fit = rfe.fit(features, labels)
# Out:
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from pandas import DataFrame
Selected = DataFrame(rfe.support_, columns = ["RFE"], index=features.columns)
Selected = Selected.reset_index()

# %%
Selected[Selected['RFE'] == True]
# Out:
#                           index   RFE
# 0                  CARD_PROM_12  True
# 4                DONOR_GENDER_F  True
# 5                DONOR_GENDER_M  True
# 8         FREQUENCY_STATUS_97NK  True
# 9                    HOME_OWNER  True
# 10                 INCOME_GROUP  True
# 11                     IN_HOUSE  True
# 24       MONTHS_SINCE_LAST_GIFT  True
# 25  MONTHS_SINCE_LAST_PROM_RESP  True
# 28               NUMBER_PROM_12  True
# 29               OVERLAY_SOURCE  True
# 35                     PEP_STAR  True
# 37              PUBLISHED_PHONE  True
# 41   RECENT_CARD_RESPONSE_COUNT  True
# 42    RECENT_CARD_RESPONSE_PROP  True
# 43        RECENT_RESPONSE_COUNT  True
# 44         RECENT_RESPONSE_PROP  True
# 45           RECENT_STAR_STATUS  True
# 46                          SES  True
# 48                WEALTH_RATING  True

# %% [markdown]
# ### Variable Importance - Extratrees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(features, labels)

print(model.feature_importances_)
# Out:
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.01823088 0.02409288 0.02758255 0.02575551 0.01398664 0.01240573
#  0.02191875 0.02096209 0.0186199  0.01469663 0.0235649  0.00575665
#  0.02057339 0.02098369 0.02357283 0.02082855 0.02178428 0.02193776
#  0.02007947 0.02083795 0.02380052 0.02579542 0.02678248 0.0238721
#  0.02569898 0.02398785 0.01990283 0.01925366 0.02311585 0.01954786
#  0.01848869 0.02544742 0.02504709 0.02658617 0.02557926 0.0091643
#  0.02556664 0.01459445 0.0111235  0.01878219 0.02088055 0.01580383
#  0.02355962 0.01955904 0.02461488 0.00836471 0.01772736 0.02044797
#  0.01873372]

# %%
from pandas import DataFrame
FI = DataFrame(model.feature_importances_, columns = ["Extratrees"], index=features.columns)

# %%
FI = FI.reset_index()

# %%
FI.sort_values(['Extratrees'],ascending=0)
# Out:
#                           index  Extratrees
# 2                CONTROL_NUMBER    0.027583
# 22      MEDIAN_HOUSEHOLD_INCOME    0.026782
# 33               PCT_ATTRIBUTE4    0.026586
# 21            MEDIAN_HOME_VALUE    0.025795
# 3                     DONOR_AGE    0.025756
# 24       MONTHS_SINCE_LAST_GIFT    0.025699
# 34           PCT_OWNER_OCCUPIED    0.025579
# 36            PER_CAPITA_INCOME    0.025567
# 31               PCT_ATTRIBUTE2    0.025447
# 32               PCT_ATTRIBUTE3    0.025047
# 44         RECENT_RESPONSE_PROP    0.024615
# 1                  CLUSTER_CODE    0.024093
# 25  MONTHS_SINCE_LAST_PROM_RESP    0.023988
# 23      MONTHS_SINCE_FIRST_GIFT    0.023872
# 20                LIFETIME_PROM    0.023801
# 14           LIFETIME_CARD_PROM    0.023573
# 10                 INCOME_GROUP    0.023565
# 42    RECENT_CARD_RESPONSE_PROP    0.023560
# 28               NUMBER_PROM_12    0.023116
# 17          LIFETIME_GIFT_RANGE    0.021938
# 6                 FILE_AVG_GIFT    0.021919
# 16          LIFETIME_GIFT_COUNT    0.021784
# 13        LIFETIME_AVG_GIFT_AMT    0.020984
# 7                FILE_CARD_GIFT    0.020962
# 40          RECENT_AVG_GIFT_AMT    0.020881
# 19        LIFETIME_MIN_GIFT_AMT    0.020838
# 15         LIFETIME_GIFT_AMOUNT    0.020829
# 12                LAST_GIFT_AMT    0.020573
# 47                   URBANICITY    0.020448
# 18        LIFETIME_MAX_GIFT_AMT    0.020079
# 26          MONTHS_SINCE_ORIGIN    0.019903
# 43        RECENT_RESPONSE_COUNT    0.019559
# 29               OVERLAY_SOURCE    0.019548
# 27                 MOR_HIT_RATE    0.019254
# 39     RECENT_AVG_CARD_GIFT_AMT    0.018782
# 48                WEALTH_RATING    0.018734
# 8         FREQUENCY_STATUS_97NK    0.018620
# 30               PCT_ATTRIBUTE1    0.018489
# 0                  CARD_PROM_12    0.018231
# 46                          SES    0.017727
# 41   RECENT_CARD_RESPONSE_COUNT    0.015804
# 9                    HOME_OWNER    0.014697
# 37              PUBLISHED_PHONE    0.014594
# 4                DONOR_GENDER_F    0.013987
# 5                DONOR_GENDER_M    0.012406
# 38          RECENCY_STATUS_96NK    0.011124
# 35                     PEP_STAR    0.009164
# 45           RECENT_STAR_STATUS    0.008365
# 11                     IN_HOUSE    0.005757

# %% [markdown]
# # CHI-SQUARE

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

model = SelectKBest(score_func=chi2, k=5)
fit = model.fit(features.abs(), labels)

# %%
from pandas import DataFrame
pd.options.display.float_format = '{:.2f}'.format
chi_sq = DataFrame(fit.scores_, columns = ["Chi_Square"], index=features.columns)

# %%
chi_sq = chi_sq.reset_index()

# %%
chi_sq.sort_values('Chi_Square',ascending=0)
# Out:
#                           index  Chi_Square
# 2                CONTROL_NUMBER   378676.84
# 36            PER_CAPITA_INCOME   159846.83
# 21            MEDIAN_HOME_VALUE    42021.80
# 15         LIFETIME_GIFT_AMOUNT     3549.90
# 22      MEDIAN_HOUSEHOLD_INCOME     2227.72
# 26          MONTHS_SINCE_ORIGIN     1770.96
# 23      MONTHS_SINCE_FIRST_GIFT     1740.78
# 16          LIFETIME_GIFT_COUNT     1465.68
# 20                LIFETIME_PROM      987.28
# 7                FILE_CARD_GIFT      868.61
# 12                LAST_GIFT_AMT      779.86
# 40          RECENT_AVG_GIFT_AMT      726.61
# 19        LIFETIME_MIN_GIFT_AMT      634.24
# 13        LIFETIME_AVG_GIFT_AMT      523.91
# 6                 FILE_AVG_GIFT      523.91
# 43        RECENT_RESPONSE_COUNT      441.97
# 41   RECENT_CARD_RESPONSE_COUNT      420.61
# 18        LIFETIME_MAX_GIFT_AMT      357.71
# 14           LIFETIME_CARD_PROM      326.96
# 38          RECENCY_STATUS_96NK      278.08
# 8         FREQUENCY_STATUS_97NK      222.58
# 24       MONTHS_SINCE_LAST_GIFT      139.84
# 35                     PEP_STAR      106.63
# 27                 MOR_HIT_RATE       83.79
# 3                     DONOR_AGE       69.39
# 1                  CLUSTER_CODE       59.33
# 39     RECENT_AVG_CARD_GIFT_AMT       55.80
# 25  MONTHS_SINCE_LAST_PROM_RESP       51.71
# 28               NUMBER_PROM_12       51.68
# 34           PCT_OWNER_OCCUPIED       32.37
# 11                     IN_HOUSE       30.13
# 42    RECENT_CARD_RESPONSE_PROP       29.63
# 46                          SES       19.81
# 33               PCT_ATTRIBUTE4       19.02
# 44         RECENT_RESPONSE_PROP       18.53
# 10                 INCOME_GROUP       15.79
# 17          LIFETIME_GIFT_RANGE       15.42
# 32               PCT_ATTRIBUTE3       15.28
# 48                WEALTH_RATING       11.38
# 0                  CARD_PROM_12        8.75
# 31               PCT_ATTRIBUTE2        6.42
# 29               OVERLAY_SOURCE        6.27
# 30               PCT_ATTRIBUTE1        6.06
# 9                    HOME_OWNER        1.94
# 5                DONOR_GENDER_M        0.46
# 45           RECENT_STAR_STATUS        0.29
# 37              PUBLISHED_PHONE        0.10
# 47                   URBANICITY        0.06
# 4                DONOR_GENDER_F        0.04

# %% [markdown]
# ## L1 Feature Selection

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(features, labels)
model = SelectFromModel(lsvc,prefit=True)

# %%
from pandas import DataFrame
l1 = DataFrame(model.get_support(), columns = ["L1"], index=features.columns)
l1 = l1.reset_index()

# %%
l1[l1['L1'] == True]
# Out:
#                           index    L1
# 0                  CARD_PROM_12  True
# 1                  CLUSTER_CODE  True
# 3                     DONOR_AGE  True
# 8         FREQUENCY_STATUS_97NK  True
# 9                    HOME_OWNER  True
# 10                 INCOME_GROUP  True
# 11                     IN_HOUSE  True
# 12                LAST_GIFT_AMT  True
# 13        LIFETIME_AVG_GIFT_AMT  True
# 14           LIFETIME_CARD_PROM  True
# 15         LIFETIME_GIFT_AMOUNT  True
# 16          LIFETIME_GIFT_COUNT  True
# 18        LIFETIME_MAX_GIFT_AMT  True
# 19        LIFETIME_MIN_GIFT_AMT  True
# 20                LIFETIME_PROM  True
# 21            MEDIAN_HOME_VALUE  True
# 22      MEDIAN_HOUSEHOLD_INCOME  True
# 23      MONTHS_SINCE_FIRST_GIFT  True
# 24       MONTHS_SINCE_LAST_GIFT  True
# 25  MONTHS_SINCE_LAST_PROM_RESP  True
# 26          MONTHS_SINCE_ORIGIN  True
# 27                 MOR_HIT_RATE  True
# 28               NUMBER_PROM_12  True
# 29               OVERLAY_SOURCE  True
# 30               PCT_ATTRIBUTE1  True
# 31               PCT_ATTRIBUTE2  True
# 32               PCT_ATTRIBUTE3  True
# 33               PCT_ATTRIBUTE4  True
# 34           PCT_OWNER_OCCUPIED  True
# 35                     PEP_STAR  True
# 37              PUBLISHED_PHONE  True
# 38          RECENCY_STATUS_96NK  True
# 39     RECENT_AVG_CARD_GIFT_AMT  True
# 40          RECENT_AVG_GIFT_AMT  True
# 41   RECENT_CARD_RESPONSE_COUNT  True
# 45           RECENT_STAR_STATUS  True
# 46                          SES  True
# 47                   URBANICITY  True

# %% [markdown]
# # COMBINE ALL TOGETHER

# %%
from functools import reduce
dfs = [IV, VI, Selected, FI, chi_sq, l1]
final_results = reduce(lambda left,right: pd.merge(left,right,on='index'), dfs)

# %% [markdown]
# ## Vote each variable

# %%
columns = ['IV', 'RF', 'Extratrees', 'Chi_Square']

score_table = pd.DataFrame({},[])
score_table['index'] = final_results['index']

for i in columns:
    score_table[i] = final_results['index'].isin(list(final_results.nlargest(5,i)['index'])).astype(int)
    
score_table['RFE'] = final_results['RFE'].astype(int)
score_table['L1'] = final_results['L1'].astype(int)

# %%
score_table['final_score'] = score_table.sum(axis=1)

# %%
score_table.sort_values('final_score',ascending=0)
# Out:
#                           index  IV  RF  Extratrees  Chi_Square  RFE  L1  \
# 22      MEDIAN_HOUSEHOLD_INCOME   0   1           1           1    0   1
# 21            MEDIAN_HOME_VALUE   0   1           1           1    0   1
# 2                CONTROL_NUMBER   0   1           1           1    0   0
# 41   RECENT_CARD_RESPONSE_COUNT   1   0           0           0    1   1
# 8         FREQUENCY_STATUS_97NK   1   0           0           0    1   1
# 35                     PEP_STAR   0   0           0           0    1   1
# 25  MONTHS_SINCE_LAST_PROM_RESP   0   0           0           0    1   1
# 28               NUMBER_PROM_12   0   0           0           0    1   1
# 29               OVERLAY_SOURCE   0   0           0           0    1   1
# 33               PCT_ATTRIBUTE4   0   0           1           0    0   1
# 34           PCT_OWNER_OCCUPIED   0   1           0           0    0   1
# 0                  CARD_PROM_12   0   0           0           0    1   1
# 36            PER_CAPITA_INCOME   0   1           0           1    0   0
# 43        RECENT_RESPONSE_COUNT   1   0           0           0    1   0
# 44         RECENT_RESPONSE_PROP   1   0           0           0    1   0
# 45           RECENT_STAR_STATUS   0   0           0           0    1   1
# 46                          SES   0   0           0           0    1   1
# 37              PUBLISHED_PHONE   0   0           0           0    1   1
# 24       MONTHS_SINCE_LAST_GIFT   0   0           0           0    1   1
# 3                     DONOR_AGE   0   0           1           0    0   1
# 15         LIFETIME_GIFT_AMOUNT   0   0           0           1    0   1
# 9                    HOME_OWNER   0   0           0           0    1   1
# 10                 INCOME_GROUP   0   0           0           0    1   1
# 11                     IN_HOUSE   0   0           0           0    1   1
# 19        LIFETIME_MIN_GIFT_AMT   0   0           0           0    0   1
# 20                LIFETIME_PROM   0   0           0           0    0   1
# 47                   URBANICITY   0   0           0           0    0   1
# 4                DONOR_GENDER_F   0   0           0           0    1   0
# 5                DONOR_GENDER_M   0   0           0           0    1   0
# 6                 FILE_AVG_GIFT   1   0           0           0    0   0
# 42    RECENT_CARD_RESPONSE_PROP   0   0           0           0    1   0
# 40          RECENT_AVG_GIFT_AMT   0   0           0           0    0   1
# 39     RECENT_AVG_CARD_GIFT_AMT   0   0           0           0    0   1
# 38          RECENCY_STATUS_96NK   0   0           0           0    0   1
# 12                LAST_GIFT_AMT   0   0           0           0    0   1
# 13        LIFETIME_AVG_GIFT_AMT   0   0           0           0    0   1
# 32               PCT_ATTRIBUTE3   0   0           0           0    0   1
# 31               PCT_ATTRIBUTE2   0   0           0           0    0   1
# 30               PCT_ATTRIBUTE1   0   0           0           0    0   1
# 14           LIFETIME_CARD_PROM   0   0           0           0    0   1
# 27                 MOR_HIT_RATE   0   0           0           0    0   1
# 26          MONTHS_SINCE_ORIGIN   0   0           0           0    0   1
# 16          LIFETIME_GIFT_COUNT   0   0           0           0    0   1
# 1                  CLUSTER_CODE   0   0           0           0    0   1
# 23      MONTHS_SINCE_FIRST_GIFT   0   0           0           0    0   1
# 18        LIFETIME_MAX_GIFT_AMT   0   0           0           0    0   1
# 48                WEALTH_RATING   0   0           0           0    1   0
# 7                FILE_CARD_GIFT   0   0           0           0    0   0
# 17          LIFETIME_GIFT_RANGE   0   0           0           0    0   0
#
#     final_score
# 22            4
# 21            4
# 2             3
# 41            3
# 8             3
# 35            2
# 25            2
# 28            2
# 29            2
# 33            2
# 34            2
# 0             2
# 36            2
# 43            2
# 44            2
# 45            2
# 46            2
# 37            2
# 24            2
# 3             2
# 15            2
# 9             2
# 10            2
# 11            2
# 19            1
# 20            1
# 47            1
# 4             1
# 5             1
# 6             1
# 42            1
# 40            1
# 39            1
# 38            1
# 12            1
# 13            1
# 32            1
# 31            1
# 30            1
# 14            1
# 27            1
# 26            1
# 16            1
# 1             1
# 23            1
# 18            1
# 48            1
# 7             0
# 17            0

# %% [markdown]
# ## Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(features):
    vif = pd.DataFrame()
    vif["Features"] = features.columns
    vif["VIF"] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]    
    return(vif)

# %%
features = features[list(score_table[score_table['final_score'] >= 2]['index'])]

# %%
features.dtypes
# Out:
# CARD_PROM_12                     int64
# CONTROL_NUMBER                   int64
# DONOR_AGE                      float64
# FREQUENCY_STATUS_97NK            int64
# HOME_OWNER                        int8
# INCOME_GROUP                   float64
# IN_HOUSE                         int64
# LIFETIME_GIFT_AMOUNT           float64
# MEDIAN_HOME_VALUE                int64
# MEDIAN_HOUSEHOLD_INCOME          int64
# MONTHS_SINCE_LAST_GIFT           int64
# MONTHS_SINCE_LAST_PROM_RESP    float64
# NUMBER_PROM_12                   int64
# OVERLAY_SOURCE                    int8
# PCT_ATTRIBUTE4                   int64
# PCT_OWNER_OCCUPIED               int64
# PEP_STAR                         int64
# PER_CAPITA_INCOME                int64
# PUBLISHED_PHONE                  int64
# RECENT_CARD_RESPONSE_COUNT       int64
# RECENT_RESPONSE_COUNT            int64
# RECENT_RESPONSE_PROP           float64
# RECENT_STAR_STATUS               int64
# SES                              int32
# dtype: object

# %%
vif = calculate_vif(features)
while vif['VIF'][vif['VIF'] > 10].any():
    remove = vif.sort_values('VIF',ascending=0)['Features'][:1]
    features.drop(remove,axis=1,inplace=True)
    vif = calculate_vif(features)

# %%
list(vif['Features'])
# Out:
# ['CONTROL_NUMBER',
#  'FREQUENCY_STATUS_97NK',
#  'HOME_OWNER',
#  'INCOME_GROUP',
#  'IN_HOUSE',
#  'LIFETIME_GIFT_AMOUNT',
#  'MEDIAN_HOME_VALUE',
#  'OVERLAY_SOURCE',
#  'PCT_ATTRIBUTE4',
#  'PCT_OWNER_OCCUPIED',
#  'PEP_STAR',
#  'PUBLISHED_PHONE',
#  'RECENT_CARD_RESPONSE_COUNT',
#  'RECENT_STAR_STATUS',
#  'SES']

# %%
features.describe()
# Out:
#        CONTROL_NUMBER  FREQUENCY_STATUS_97NK  HOME_OWNER  INCOME_GROUP  \
# count        19372.00               19372.00    19372.00      19372.00
# mean         96546.23                   1.98        0.45          4.16
# std          55830.64                   1.10        0.50          1.70
# min              5.00                   1.00        0.00          1.00
# 25%          48289.00                   1.00        0.00          3.00
# 50%          96937.00                   2.00        0.00          5.00
# 75%         145429.50                   3.00        1.00          5.00
# max         191779.00                   4.00        1.00          7.00
#
#        IN_HOUSE  LIFETIME_GIFT_AMOUNT  MEDIAN_HOME_VALUE  OVERLAY_SOURCE  \
# count  19372.00              19372.00           19372.00        19372.00
# mean       0.07                104.43            1079.87            1.27
# std        0.26                105.72             960.75            1.26
# min        0.00                 15.00               0.00            0.00
# 25%        0.00                 42.00             518.00            0.00
# 50%        0.00                 79.00             747.00            1.00
# 75%        0.00                132.00            1227.00            2.00
# max        1.00               3775.00            6000.00            3.00
#
#        PCT_ATTRIBUTE4  PCT_OWNER_OCCUPIED  PEP_STAR  PUBLISHED_PHONE  \
# count        19372.00            19372.00  19372.00         19372.00
# mean            32.85               69.70      0.50             0.50
# std             17.84               21.71      0.50             0.50
# min              0.00                0.00      0.00             0.00
# 25%             21.00               60.00      0.00             0.00
# 50%             32.00               76.00      1.00             0.00
# 75%             43.00               85.00      1.00             1.00
# max             99.00               99.00      1.00             1.00
#
#        RECENT_CARD_RESPONSE_COUNT  RECENT_STAR_STATUS      SES
# count                    19372.00            19372.00 19372.00
# mean                         1.73                0.93     0.91
# std                          1.54                2.55     0.74
# min                          0.00                0.00     0.00
# 25%                          1.00                0.00     0.00
# 50%                          1.00                0.00     1.00
# 75%                          2.00                1.00     1.00
# max                          9.00               22.00     3.00

# %%
features.head()
# Out:
#    CONTROL_NUMBER  FREQUENCY_STATUS_97NK  HOME_OWNER  INCOME_GROUP  IN_HOUSE  \
# 0               5                      1           0          2.00         0
# 1              12                      2           0          7.00         0
# 2              37                      3           0          5.00         0
# 3              38                      3           0          6.00         0
# 4              41                      1           1          2.00         0
#
#    LIFETIME_GIFT_AMOUNT  MEDIAN_HOME_VALUE  OVERLAY_SOURCE  PCT_ATTRIBUTE4  \
# 0                297.00                554               3               0
# 1                368.00                334               3              31
# 2                603.00               2388               3              57
# 3                435.00               1688               0              42
# 4                106.00                514               0              37
#
#    PCT_OWNER_OCCUPIED  PEP_STAR  PUBLISHED_PHONE  RECENT_CARD_RESPONSE_COUNT  \
# 0                  76         1                0                           0
# 1                  72         1                0                           2
# 2                  63         1                0                           6
# 3                   3         1                1                           4
# 4                  90         0                1                           1
#
#    RECENT_STAR_STATUS  SES
# 0                   0    1
# 1                   1    1
# 2                   1    0
# 3                   0    1
# 4                   0    1

# %%
#Merge the best list to churn variable
final_vars = list(vif['Features']) + ['Donated']

# %%
df1 = data[final_vars].fillna(0)

# %%
df1.describe()
# Out:
#        CONTROL_NUMBER  FREQUENCY_STATUS_97NK  HOME_OWNER  INCOME_GROUP  \
# count        19372.00               19372.00    19372.00      19372.00
# mean         96546.23                   1.98        0.45          4.16
# std          55830.64                   1.10        0.50          1.70
# min              5.00                   1.00        0.00          1.00
# 25%          48289.00                   1.00        0.00          3.00
# 50%          96937.00                   2.00        0.00          5.00
# 75%         145429.50                   3.00        1.00          5.00
# max         191779.00                   4.00        1.00          7.00
#
#        IN_HOUSE  LIFETIME_GIFT_AMOUNT  MEDIAN_HOME_VALUE  OVERLAY_SOURCE  \
# count  19372.00              19372.00           19372.00        19372.00
# mean       0.07                104.43            1079.87            1.27
# std        0.26                105.72             960.75            1.26
# min        0.00                 15.00               0.00            0.00
# 25%        0.00                 42.00             518.00            0.00
# 50%        0.00                 79.00             747.00            1.00
# 75%        0.00                132.00            1227.00            2.00
# max        1.00               3775.00            6000.00            3.00
#
#        PCT_ATTRIBUTE4  PCT_OWNER_OCCUPIED  PEP_STAR  PUBLISHED_PHONE  \
# count        19372.00            19372.00  19372.00         19372.00
# mean            32.85               69.70      0.50             0.50
# std             17.84               21.71      0.50             0.50
# min              0.00                0.00      0.00             0.00
# 25%             21.00               60.00      0.00             0.00
# 50%             32.00               76.00      1.00             0.00
# 75%             43.00               85.00      1.00             1.00
# max             99.00               99.00      1.00             1.00
#
#        RECENT_CARD_RESPONSE_COUNT  RECENT_STAR_STATUS      SES  Donated
# count                    19372.00            19372.00 19372.00 19372.00
# mean                         1.73                0.93     0.91     0.25
# std                          1.54                2.55     0.74     0.43
# min                          0.00                0.00     0.00     0.00
# 25%                          1.00                0.00     0.00     0.00
# 50%                          1.00                0.00     1.00     0.00
# 75%                          2.00                1.00     1.00     0.25
# max                          9.00               22.00     3.00     1.00

# %%
bar_color = '#058caa'
num_color = '#ed8549'

final_iv,_ = data_vars(df1,df1['Donated'])
final_iv = final_iv[(final_iv.VAR_NAME != 'Donated')]
grouped = final_iv.groupby(['VAR_NAME'])
for key, group in grouped:
    ax = group.plot('MIN_VALUE','EVENT_RATE',kind='bar',color=bar_color,linewidth=1.0,edgecolor=['black'])
    ax.set_title(str(key) + " vs " + str('target'))
    ax.set_xlabel(key)
    ax.set_ylabel(str('target') + " %")
    rects = ax.patches
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.01*height, str(round(height*100,1)) + '%', 
                ha='center', va='bottom', color=num_color, fontweight='bold')

# %%
# Calculate correlations
corr = df1.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
# Heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(corr,
            vmax=.5,
            mask=mask,
            # annot=True, fmt='.2f',
            linewidths=.2, cmap="YlGnBu")

# %% [markdown]
# ## CROSS VALIDATION

# %%
#https://stackabuse.com/cross-validation-and-grid-search-for-model-selection-in-python/
from sklearn.model_selection import train_test_split

train, test = train_test_split(df1, test_size=0.2, random_state=20)
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

features_train = train[list(vif['Features'])]
label_train = train['Donated']
features_test = test[list(vif['Features'])]
label_test = test['Donated']

# %%
#implement cross validation, the cross_val_score method of the sklearn.model_selection library can be used. 
from sklearn.ensemble import RandomForestClassifier  
classifier = RandomForestClassifier(n_estimators=300, random_state=20)

# %%
from sklearn.model_selection import cross_val_score  
all_accuracies = cross_val_score(estimator=classifier, X=features_train, y=label_train, cv=10)

# %%
print(all_accuracies)
# Out:
# [0.74983881 0.75032258 0.74387097 0.74903226 0.74645161 0.75677419
#  0.74370562 0.74822466 0.74112331 0.74757908]

# %%
#find the average of all the accuracies, simple use the mean() method of the object returned by cross_val_score
print(all_accuracies.mean())
# Out:
# 0.7476923092808109

# %%
#Finally let's find the standard deviation of the data to see degree of variance in the results obtained by our model. To do so, call the std() method on the all_accuracies object
print(all_accuracies.std())
# Out:
# 0.004138666717593573

# %% [markdown]
# ## Let's Try Cross Validation using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
all_accuracies = cross_val_score(estimator=clf, X=features_train, y=label_train, cv=10)
# Out:
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print(all_accuracies)
# Out:
# [0.74919407 0.75032258 0.74903226 0.74967742 0.74967742 0.74967742
#  0.75080697 0.74951582 0.75016139 0.75016139]

# %%
#find the average of all the accuracies, simple use the mean() method of the object returned by cross_val_score
print(all_accuracies.mean())
# Out:
# 0.7498226742909322

# %%
#Finally let's find the standard deviation of the data to see degree of variance in the results obtained by our model. To do so, call the std() method on the all_accuracies object
print(all_accuracies.std())
# Out:
# 0.0005124034886489836

# %% [markdown]
# ## Grid Search for Parameter Selection
# instead of randomly selecting the values of the parameters, a better approach would be to develop an algorithm which automatically finds the best parameters for a particular model. Grid Search is one such algorithm.

# %%
#https://stackabuse.com/cross-validation-and-grid-search-for-model-selection-in-python/
grid_param = {  
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False]
}

# %%
from sklearn.model_selection import GridSearchCV
gd_sr = GridSearchCV(estimator=classifier,  
                     param_grid=grid_param,
                     scoring='accuracy',
                     cv=10,
                     n_jobs=-1)

# %%
#Once the GridSearchCV class is initialized, the last step is to call the fit method of the class and pass it the training and 
#test set, as shown in the following code:
gd_sr.fit(features_train, label_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=300, n_jobs=None,
#                                               oob_score=False, random_state=20,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'n_estimators': [50, 100, 150]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
#the next step is to check the parameters that return the highest accuracy
best_parameters = gd_sr.best_params_  
print(best_parameters)
# Out:
# {'bootstrap': True, 'criterion': 'entropy', 'n_estimators': 150}

# %%
#To find the best accuracy achieved, execute the following code:
best_result = gd_sr.best_score_  
print(best_result)
# Out:
# 0.747112344324708

# %% [markdown]
# # Model Assessment & Selection

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df1, test_size = 0.2)
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

features_train = train[list(vif['Features'])]
label_train = train['Donated']
features_test = test[list(vif['Features'])]
label_test = test['Donated']

# %%
all_features = pd.concat([features_train, features_test])
all_labels = pd.concat([label_train, label_test])

# %%
# stochastic gradient descent (SGD) learning
sgd = linear_model.SGDClassifier(max_iter=10, tol=None)
sgd.fit(features_train, label_train)
y_pred = sgd.predict(features_test)

sgd.score(features_train, label_train)

acc_sgd = round(sgd.score(features_train, label_train) * 100, 2)
print(round(acc_sgd,2,), "%")
# Out:
# 74.85 %

# %%
## Random Forest
random_forest = RandomForestClassifier(n_estimators=70)
random_forest.fit(features_train, label_train)

y_prediction = random_forest.predict(features_test)

random_forest.score(features_train, label_train)
acc_random_forest = round(random_forest.score(features_train, label_train) * 100, 2)
print(round(acc_random_forest,2,), "%")
# Out:
# 100.0 %

# %%
# Logistic Regression
logreg = LogisticRegression()
logreg.fit(features_train, label_train)

y_pred = logreg.predict(features_test)

acc_log = round(logreg.score(features_train, label_train) * 100, 2)
print(round(acc_log,2,), "%")
# Out:
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 74.9 %

# %%
# KNN
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(features_train, label_train)

y_pred = knn.predict(features_test)

acc_knn = round(knn.score(features_train, label_train) * 100, 2)
print(round(acc_knn,2,), "%")
# Out:
# 81.46 %

# %%
# Naive Bayes
gaussian = GaussianNB()
gaussian.fit(features_train, label_train)

y_pred = gaussian.predict(features_test)

acc_gaussian = round(gaussian.score(features_train, label_train) * 100, 2)
print(round(acc_gaussian,2,), "%")
# Out:
# 73.54 %

# %%
#PERCEPTON

perceptron = Perceptron(max_iter=5)
perceptron.fit(features_train, label_train)

y_pred = perceptron.predict(features_test)

acc_perceptron = round(perceptron.score(features_train, label_train) * 100, 2)
print(round(acc_perceptron,2,), "%")
# Out:
# 74.72 %
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\stochastic_gradient.py:561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)

# %%
# Linear SVC
linear_svc = LinearSVC()
linear_svc.fit(features_train, label_train)

y_pred = linear_svc.predict(features_test)

acc_linear_svc = round(linear_svc.score(features_train, label_train) * 100, 2)
print(round(acc_linear_svc,2,), "%")
# Out:
# 69.16 %
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
# DECISION TREE
decision_tree = DecisionTreeClassifier()
decision_tree.fit(features_train, label_train)

y_pred = decision_tree.predict(features_test)

acc_decision_tree = round(decision_tree.score(features_train, label_train) * 100, 2)
print(round(acc_decision_tree,2,), "%")
# Out:
# 100.0 %

# %%
# MODEL COMPARISON

results = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 
              'Decision Tree'],
    'Score': [acc_linear_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_decision_tree]})
result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df.head(9)
# Out:
#                              Model
# Score
# 100.00               Random Forest
# 100.00               Decision Tree
# 81.46                          KNN
# 74.90          Logistic Regression
# 74.85   Stochastic Gradient Decent
# 74.72                   Perceptron
# 73.54                  Naive Bayes
# 69.16      Support Vector Machines

# %%
# K-Fold cross validation
from sklearn.model_selection import cross_val_score
rf = RandomForestClassifier(n_estimators=100)
scores = cross_val_score(rf, features_train, label_train, cv=10, scoring = "accuracy")

# %%
print("Scores:", scores)
print("Mean:", scores.mean())
print("Standard Deviation:", scores.std())
# Out:
# Scores: [0.74725983 0.74709677 0.74258065 0.74645161 0.74645161 0.74645161
#  0.74176888 0.74370562 0.74887024 0.74757908]
# Mean: 0.745821591225126
# Standard Deviation: 0.0022062176892813264

# %%
# FEATURE IMPORTANCE

# %%
importances = pd.DataFrame({'feature':features_train.columns,'importance':np.round(random_forest.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')

# %%
importances.head(15)
# Out:
#                             importance
# feature
# CONTROL_NUMBER                    0.16
# MEDIAN_HOME_VALUE                 0.15
# LIFETIME_GIFT_AMOUNT              0.14
# PCT_OWNER_OCCUPIED                0.13
# PCT_ATTRIBUTE4                    0.13
# INCOME_GROUP                      0.06
# RECENT_CARD_RESPONSE_COUNT        0.05
# OVERLAY_SOURCE                    0.03
# FREQUENCY_STATUS_97NK             0.03
# SES                               0.03
# RECENT_STAR_STATUS                0.02
# PUBLISHED_PHONE                   0.02
# HOME_OWNER                        0.02
# PEP_STAR                          0.01
# IN_HOUSE                          0.01

# %%
importances.plot.bar()

# %%
#Train the final model on all the dataset
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(**best_parameters)

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)



print(accuracy_train, accuracy_test)
# Out:
# 1.0 0.7504516129032258

# %%
# Tuning for Random Forest with RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(3, 10, num = 1)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

rf = RandomForestClassifier()

rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 10, cv = 2, verbose=2, random_state=42, n_jobs = -1)
rf_random.fit(features_train,label_train)
              
print(rf_random.best_params_)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   30.1s finished
# {'n_estimators': 227, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 3, 'bootstrap': True}

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(**rf_random.best_params_)

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test)
# Out:
# 0.7492417887333033 0.7530322580645161

# %% [markdown]
# ## Save Model for future use

# %%
import pandas
from sklearn.externals import joblib

filename = 'final_donor_model.model'
i = [d,clf]
joblib.dump(i,filename)
# Out:
# C:\Users\EO\AppData\Roaming\Python\Python37\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['final_donor_model.model']

# %% [markdown]
# ## Score New Data

# %%
features.dtypes
# Out:
# CONTROL_NUMBER                  int64
# FREQUENCY_STATUS_97NK           int64
# HOME_OWNER                       int8
# INCOME_GROUP                  float64
# IN_HOUSE                        int64
# LIFETIME_GIFT_AMOUNT          float64
# MEDIAN_HOME_VALUE               int64
# OVERLAY_SOURCE                   int8
# PCT_ATTRIBUTE4                  int64
# PCT_OWNER_OCCUPIED              int64
# PEP_STAR                        int64
# PUBLISHED_PHONE                 int64
# RECENT_CARD_RESPONSE_COUNT      int64
# RECENT_STAR_STATUS              int64
# SES                             int32
# dtype: object

# %%
#Prepare score data to ensure the attributes of the modelling data matches that of the scoring data
#Score_data


path1 = "C:/Users/EO/Desktop/Josh Folder/downloads/ML ASSIGNMENT/Prospective Donor_ML with Python.csv"
data1 = pd.read_csv(path1)
data1.head()
# Out:
#    CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE URBANICITY SES  \
# 0             139                  101        nan         0          R   2
# 1             142                  137        nan         0          R   2
# 2             282                   17      30.00         0          T   1
# 3             368                  137      75.00         0          U   1
# 4             387                    5        nan         0          T   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           46          U            F           nan                0
# 1           43          U            F           nan                1
# 2           35          H            M          6.00                1
# 3           02          H            M          6.00                1
# 4           40          U            F          2.00                0
#
#   OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0              N             0            nan                655
# 1              N             0           1.00                475
# 2              B            11            nan               1117
# 3              B             1           7.00               2257
# 4              B             0            nan                789
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      219                  77              12671
# 1                      227                  70              10221
# 2                      544                  87              18212
# 3                      485                  84              17885
# 4                      413                  97              14123
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0              46              24              53         0
# 1               0              30              33              29         1
# 2               1              27              70              21         0
# 3               0              43              28              41         1
# 4               0              31              16               7         0
#
#    RECENT_STAR_STATUS RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                   A                      1
# 1                   1                   S                      2
# 2                   0                   F                      1
# 3                  10                   A                      1
# 4                   0                   A                      3
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                  0.07                21.00                       0.00
# 1                  0.35                10.00                       0.50
# 2                  0.08                20.00                       0.20
# 3                  0.33                 8.83                       0.44
# 4                  0.28                 5.40                       0.22
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     10.00                      7
# 2                     20.00                      1
# 3                      8.75                      6
# 4                      6.00                      5
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           5                        22.00
# 2                           1                        20.00
# 3                           4                        19.00
# 4                           2                        20.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  11             25                103.00
# 1                  44            110                186.00
# 2                  13             39                 76.00
# 3                  42            114                247.00
# 4                  15             43                 70.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                    7                  14.71                16.00
# 1                   31                   6.00                 9.00
# 2                    9                   8.44                15.00
# 3                   38                   6.50                 5.00
# 4                   12                   5.83                 7.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  21.00                   5.00          21.00             4
# 1                  11.00                   2.00          10.00             9
# 2                  20.00                   5.00          20.00             5
# 3                  10.00                   5.00          10.00            10
# 4                  10.00                   3.00           5.00             5
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              10                      26                       90
# 1              22                      22                      129
# 2              14                      20                       87
# 3              24                      19                      129
# 4              12                      18                       85
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0          14.71               2
# 1           6.00              14
# 2           8.44               1
# 3           6.50              22
# 4           5.83               2

# %%
#replace missing values with most frequent values
Score_data_sel = data1.fillna(data1.mode().iloc[0])

# %%
Score_data_sel.head()
# Out:
#    CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE URBANICITY SES  \
# 0             139                  101      71.00         0          R   2
# 1             142                  137      71.00         0          R   2
# 2             282                   17      30.00         0          T   1
# 3             368                  137      75.00         0          U   1
# 4             387                    5      71.00         0          T   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           46          U            F          5.00                0
# 1           43          U            F          5.00                1
# 2           35          H            M          6.00                1
# 3           02          H            M          6.00                1
# 4           40          U            F          2.00                0
#
#   OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0              N             0           9.00                655
# 1              N             0           1.00                475
# 2              B            11           9.00               1117
# 3              B             1           7.00               2257
# 4              B             0           9.00                789
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      219                  77              12671
# 1                      227                  70              10221
# 2                      544                  87              18212
# 3                      485                  84              17885
# 4                      413                  97              14123
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0              46              24              53         0
# 1               0              30              33              29         1
# 2               1              27              70              21         0
# 3               0              43              28              41         1
# 4               0              31              16               7         0
#
#    RECENT_STAR_STATUS RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                   A                      1
# 1                   1                   S                      2
# 2                   0                   F                      1
# 3                  10                   A                      1
# 4                   0                   A                      3
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                  0.07                21.00                       0.00
# 1                  0.35                10.00                       0.50
# 2                  0.08                20.00                       0.20
# 3                  0.33                 8.83                       0.44
# 4                  0.28                 5.40                       0.22
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     10.00                      7
# 2                     20.00                      1
# 3                      8.75                      6
# 4                      6.00                      5
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           5                        22.00
# 2                           1                        20.00
# 3                           4                        19.00
# 4                           2                        20.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  11             25                103.00
# 1                  44            110                186.00
# 2                  13             39                 76.00
# 3                  42            114                247.00
# 4                  15             43                 70.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                    7                  14.71                16.00
# 1                   31                   6.00                 9.00
# 2                    9                   8.44                15.00
# 3                   38                   6.50                 5.00
# 4                   12                   5.83                 7.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  21.00                   5.00          21.00             4
# 1                  11.00                   2.00          10.00             9
# 2                  20.00                   5.00          20.00             5
# 3                  10.00                   5.00          10.00            10
# 4                  10.00                   3.00           5.00             5
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              10                      26                       90
# 1              22                      22                      129
# 2              14                      20                       87
# 3              24                      19                      129
# 4              12                      18                       85
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0          14.71               2
# 1           6.00              14
# 2           8.44               1
# 3           6.50              22
# 4           5.83               2

# %%
#DO THE SAME FOR OVERLAY_SOURCE
Score_data_sel['OVERLAY_SOURCE'] = Score_data_sel['OVERLAY_SOURCE'].astype('category')
Score_data_sel['OVERLAY_SOURCE'] = Score_data_sel['OVERLAY_SOURCE'].cat.codes

# %%
#DO THE SAME FOR HOME_OWNER
Score_data_sel['HOME_OWNER'] = Score_data_sel['HOME_OWNER'].astype('category')
Score_data_sel['HOME_OWNER'] = Score_data_sel['HOME_OWNER'].cat.codes

# %%
Score_data_sel.dtypes
# Out:
# CONTROL_NUMBER                   int64
# MONTHS_SINCE_ORIGIN              int64
# DONOR_AGE                      float64
# IN_HOUSE                         int64
# URBANICITY                      object
# SES                             object
# CLUSTER_CODE                    object
# HOME_OWNER                        int8
# DONOR_GENDER                    object
# INCOME_GROUP                   float64
# PUBLISHED_PHONE                  int64
# OVERLAY_SOURCE                    int8
# MOR_HIT_RATE                     int64
# WEALTH_RATING                  float64
# MEDIAN_HOME_VALUE                int64
# MEDIAN_HOUSEHOLD_INCOME          int64
# PCT_OWNER_OCCUPIED               int64
# PER_CAPITA_INCOME                int64
# PCT_ATTRIBUTE1                   int64
# PCT_ATTRIBUTE2                   int64
# PCT_ATTRIBUTE3                   int64
# PCT_ATTRIBUTE4                   int64
# PEP_STAR                         int64
# RECENT_STAR_STATUS               int64
# RECENCY_STATUS_96NK             object
# FREQUENCY_STATUS_97NK            int64
# RECENT_RESPONSE_PROP           float64
# RECENT_AVG_GIFT_AMT            float64
# RECENT_CARD_RESPONSE_PROP      float64
# RECENT_AVG_CARD_GIFT_AMT       float64
# RECENT_RESPONSE_COUNT            int64
# RECENT_CARD_RESPONSE_COUNT       int64
# MONTHS_SINCE_LAST_PROM_RESP    float64
# LIFETIME_CARD_PROM               int64
# LIFETIME_PROM                    int64
# LIFETIME_GIFT_AMOUNT           float64
# LIFETIME_GIFT_COUNT              int64
# LIFETIME_AVG_GIFT_AMT          float64
# LIFETIME_GIFT_RANGE            float64
# LIFETIME_MAX_GIFT_AMT          float64
# LIFETIME_MIN_GIFT_AMT          float64
# LAST_GIFT_AMT                  float64
# CARD_PROM_12                     int64
# NUMBER_PROM_12                   int64
# MONTHS_SINCE_LAST_GIFT           int64
# MONTHS_SINCE_FIRST_GIFT          int64
# FILE_AVG_GIFT                  float64
# FILE_CARD_GIFT                   int64
# dtype: object

# %%
#Select features and target
Score_data_sel = Score_data_sel[['CONTROL_NUMBER',
 'FREQUENCY_STATUS_97NK',
 'HOME_OWNER',
 'INCOME_GROUP',
 'IN_HOUSE',
 'LIFETIME_GIFT_AMOUNT',
 'MEDIAN_HOME_VALUE',
 'OVERLAY_SOURCE',
 'PCT_ATTRIBUTE4',
 'PCT_OWNER_OCCUPIED',
 'PEP_STAR',
 'PUBLISHED_PHONE',
 'RECENT_CARD_RESPONSE_COUNT',
 'RECENT_STAR_STATUS',
 'SES']]

# %%
#Select features and target
Score_data_sel.head()
# Out:
#    CONTROL_NUMBER  FREQUENCY_STATUS_97NK  HOME_OWNER  INCOME_GROUP  IN_HOUSE  \
# 0             139                      1           1          5.00         0
# 1             142                      2           1          5.00         0
# 2             282                      1           0          6.00         0
# 3             368                      1           0          6.00         0
# 4             387                      3           1          2.00         0
#
#    LIFETIME_GIFT_AMOUNT  MEDIAN_HOME_VALUE  OVERLAY_SOURCE  PCT_ATTRIBUTE4  \
# 0                103.00                655               2              53
# 1                186.00                475               2              29
# 2                 76.00               1117               0              21
# 3                247.00               2257               0              41
# 4                 70.00                789               0               7
#
#    PCT_OWNER_OCCUPIED  PEP_STAR  PUBLISHED_PHONE  RECENT_CARD_RESPONSE_COUNT  \
# 0                  77         0                0                           0
# 1                  70         1                1                           5
# 2                  87         0                1                           1
# 3                  84         1                1                           4
# 4                  97         0                0                           2
#
#    RECENT_STAR_STATUS SES
# 0                   0   2
# 1                   1   2
# 2                   0   1
# 3                  10   1
# 4                   0   2

# %%
Score_data_sel.dtypes
# Out:
# CONTROL_NUMBER                  int64
# FREQUENCY_STATUS_97NK           int64
# HOME_OWNER                       int8
# INCOME_GROUP                  float64
# IN_HOUSE                        int64
# LIFETIME_GIFT_AMOUNT          float64
# MEDIAN_HOME_VALUE               int64
# OVERLAY_SOURCE                   int8
# PCT_ATTRIBUTE4                  int64
# PCT_OWNER_OCCUPIED              int64
# PEP_STAR                        int64
# PUBLISHED_PHONE                 int64
# RECENT_CARD_RESPONSE_COUNT      int64
# RECENT_STAR_STATUS              int64
# SES                            object
# dtype: object

# %%
#from object to float
Score_data_sel["SES"] = pd.to_numeric(Score_data_sel.SES, errors='coerce')

# %%
Score_data_sel = Score_data_sel.replace("?",np.nan)

# %%
#check for missing values again
Score_data_sel.isnull().sum()
# Out:
# CONTROL_NUMBER                 0
# FREQUENCY_STATUS_97NK          0
# HOME_OWNER                     0
# INCOME_GROUP                   0
# IN_HOUSE                       0
# LIFETIME_GIFT_AMOUNT           0
# MEDIAN_HOME_VALUE              0
# OVERLAY_SOURCE                 0
# PCT_ATTRIBUTE4                 0
# PCT_OWNER_OCCUPIED             0
# PEP_STAR                       0
# PUBLISHED_PHONE                0
# RECENT_CARD_RESPONSE_COUNT     0
# RECENT_STAR_STATUS             0
# SES                           54
# dtype: int64

# %%
#fill in missing values
Score_data_sel['SES']= Score_data_sel['SES'].fillna(Score_data_sel['SES'].mode().iloc[0])

# %%
#ceck again
Score_data_sel.isnull().sum()
# Out:
# CONTROL_NUMBER                0
# FREQUENCY_STATUS_97NK         0
# HOME_OWNER                    0
# INCOME_GROUP                  0
# IN_HOUSE                      0
# LIFETIME_GIFT_AMOUNT          0
# MEDIAN_HOME_VALUE             0
# OVERLAY_SOURCE                0
# PCT_ATTRIBUTE4                0
# PCT_OWNER_OCCUPIED            0
# PEP_STAR                      0
# PUBLISHED_PHONE               0
# RECENT_CARD_RESPONSE_COUNT    0
# RECENT_STAR_STATUS            0
# SES                           0
# dtype: int64

# %%
# Use the code to load the model
filename = 'final_donor_model.model'

from sklearn.externals import joblib
d,clf=joblib.load(filename)

# %%
#Score the final model (RForest) 
pred_train = clf.predict(Score_data_sel)

# %%
def score_new(features,clf):
    score = pd.DataFrame(clf.predict_proba(features)[:,1], columns = ['SCORE'])
    score['DECILE'] = pd.qcut(score['SCORE'].rank(method = 'first'),10,labels=range(10,0,-1))
    score['DECILE'] = score['DECILE'].astype(float)
    return(score)

# %%
scores = score_new(Score_data_sel,clf)

# %%
# How many 0s and 1s are there

print('There are', np.count_nonzero(pred_train == 0), '0s')

print('There are', np.count_nonzero(pred_train == 1), '1s')
# Out:
# There are 2148 0s
# There are 0 1s

# %%
Score_data_sel.head(5)
# Out:
#    CONTROL_NUMBER  FREQUENCY_STATUS_97NK  HOME_OWNER  INCOME_GROUP  IN_HOUSE  \
# 0             139                      1           1          5.00         0
# 1             142                      2           1          5.00         0
# 2             282                      1           0          6.00         0
# 3             368                      1           0          6.00         0
# 4             387                      3           1          2.00         0
#
#    LIFETIME_GIFT_AMOUNT  MEDIAN_HOME_VALUE  OVERLAY_SOURCE  PCT_ATTRIBUTE4  \
# 0                103.00                655               2              53
# 1                186.00                475               2              29
# 2                 76.00               1117               0              21
# 3                247.00               2257               0              41
# 4                 70.00                789               0               7
#
#    PCT_OWNER_OCCUPIED  PEP_STAR  PUBLISHED_PHONE  RECENT_CARD_RESPONSE_COUNT  \
# 0                  77         0                0                           0
# 1                  70         1                1                           5
# 2                  87         0                1                           1
# 3                  84         1                1                           4
# 4                  97         0                0                           2
#
#    RECENT_STAR_STATUS  SES
# 0                   0 2.00
# 1                   1 2.00
# 2                   0 1.00
# 3                  10 1.00
# 4                   0 2.00

# %%
#Convert 'Score':scores.SCORE, 'Decile':scores.DECILE to list

# %%
# Put the result in a dataframe

#pd.DataFrame({'Customer_ID':non_churners_score.Customer_ID,'Churn_Flag':DecTree_score_pred}).to_csv('Predicted Churners.csv',index=False)
# Store the result in a csv file
#, 'Score':scores.SCORE, 'Decile':scores.DECILE
Final = pd.DataFrame({'CONTROL_NUMBER':Score_data_sel.CONTROL_NUMBER,'Donation_Flag':pred_train})

# %%
path2 = "C:/Users/EO/Desktop/Josh Folder/downloads/ML ASSIGNMENT/Prospective Donor_ML with Python.csv"
data2 = pd.read_csv(path2)
data2.head()
# Out:
#    CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE URBANICITY SES  \
# 0             139                  101        nan         0          R   2
# 1             142                  137        nan         0          R   2
# 2             282                   17      30.00         0          T   1
# 3             368                  137      75.00         0          U   1
# 4             387                    5        nan         0          T   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           46          U            F           nan                0
# 1           43          U            F           nan                1
# 2           35          H            M          6.00                1
# 3           02          H            M          6.00                1
# 4           40          U            F          2.00                0
#
#   OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0              N             0            nan                655
# 1              N             0           1.00                475
# 2              B            11            nan               1117
# 3              B             1           7.00               2257
# 4              B             0            nan                789
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      219                  77              12671
# 1                      227                  70              10221
# 2                      544                  87              18212
# 3                      485                  84              17885
# 4                      413                  97              14123
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0              46              24              53         0
# 1               0              30              33              29         1
# 2               1              27              70              21         0
# 3               0              43              28              41         1
# 4               0              31              16               7         0
#
#    RECENT_STAR_STATUS RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                   A                      1
# 1                   1                   S                      2
# 2                   0                   F                      1
# 3                  10                   A                      1
# 4                   0                   A                      3
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                  0.07                21.00                       0.00
# 1                  0.35                10.00                       0.50
# 2                  0.08                20.00                       0.20
# 3                  0.33                 8.83                       0.44
# 4                  0.28                 5.40                       0.22
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     10.00                      7
# 2                     20.00                      1
# 3                      8.75                      6
# 4                      6.00                      5
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           5                        22.00
# 2                           1                        20.00
# 3                           4                        19.00
# 4                           2                        20.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  11             25                103.00
# 1                  44            110                186.00
# 2                  13             39                 76.00
# 3                  42            114                247.00
# 4                  15             43                 70.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                    7                  14.71                16.00
# 1                   31                   6.00                 9.00
# 2                    9                   8.44                15.00
# 3                   38                   6.50                 5.00
# 4                   12                   5.83                 7.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  21.00                   5.00          21.00             4
# 1                  11.00                   2.00          10.00             9
# 2                  20.00                   5.00          20.00             5
# 3                  10.00                   5.00          10.00            10
# 4                  10.00                   3.00           5.00             5
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              10                      26                       90
# 1              22                      22                      129
# 2              14                      20                       87
# 3              24                      19                      129
# 4              12                      18                       85
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0          14.71               2
# 1           6.00              14
# 2           8.44               1
# 3           6.50              22
# 4           5.83               2

# %%
#replace missing values with most frequent values
newest_data = data2.fillna(data2.mode().iloc[0])

# %%
newest_data.head()
# Out:
#    CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE URBANICITY SES  \
# 0             139                  101      71.00         0          R   2
# 1             142                  137      71.00         0          R   2
# 2             282                   17      30.00         0          T   1
# 3             368                  137      75.00         0          U   1
# 4             387                    5      71.00         0          T   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           46          U            F          5.00                0
# 1           43          U            F          5.00                1
# 2           35          H            M          6.00                1
# 3           02          H            M          6.00                1
# 4           40          U            F          2.00                0
#
#   OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0              N             0           9.00                655
# 1              N             0           1.00                475
# 2              B            11           9.00               1117
# 3              B             1           7.00               2257
# 4              B             0           9.00                789
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      219                  77              12671
# 1                      227                  70              10221
# 2                      544                  87              18212
# 3                      485                  84              17885
# 4                      413                  97              14123
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0              46              24              53         0
# 1               0              30              33              29         1
# 2               1              27              70              21         0
# 3               0              43              28              41         1
# 4               0              31              16               7         0
#
#    RECENT_STAR_STATUS RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                   A                      1
# 1                   1                   S                      2
# 2                   0                   F                      1
# 3                  10                   A                      1
# 4                   0                   A                      3
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                  0.07                21.00                       0.00
# 1                  0.35                10.00                       0.50
# 2                  0.08                20.00                       0.20
# 3                  0.33                 8.83                       0.44
# 4                  0.28                 5.40                       0.22
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     10.00                      7
# 2                     20.00                      1
# 3                      8.75                      6
# 4                      6.00                      5
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           5                        22.00
# 2                           1                        20.00
# 3                           4                        19.00
# 4                           2                        20.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  11             25                103.00
# 1                  44            110                186.00
# 2                  13             39                 76.00
# 3                  42            114                247.00
# 4                  15             43                 70.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                    7                  14.71                16.00
# 1                   31                   6.00                 9.00
# 2                    9                   8.44                15.00
# 3                   38                   6.50                 5.00
# 4                   12                   5.83                 7.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  21.00                   5.00          21.00             4
# 1                  11.00                   2.00          10.00             9
# 2                  20.00                   5.00          20.00             5
# 3                  10.00                   5.00          10.00            10
# 4                  10.00                   3.00           5.00             5
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              10                      26                       90
# 1              22                      22                      129
# 2              14                      20                       87
# 3              24                      19                      129
# 4              12                      18                       85
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0          14.71               2
# 1           6.00              14
# 2           8.44               1
# 3           6.50              22
# 4           5.83               2

# %%
newest_data = newest_data.replace("?",np.nan)

# %%
#fill in missing values AGAIN
newest_data['SES']= newest_data['SES'].fillna(newest_data['SES'].mode().iloc[0])

# %%
newest_data['URBANICITY']= newest_data['URBANICITY'].fillna(newest_data['URBANICITY'].mode().iloc[0])

# %%
newest_data.head()
# Out:
#    CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE URBANICITY SES  \
# 0             139                  101      71.00         0          R   2
# 1             142                  137      71.00         0          R   2
# 2             282                   17      30.00         0          T   1
# 3             368                  137      75.00         0          U   1
# 4             387                    5      71.00         0          T   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           46          U            F          5.00                0
# 1           43          U            F          5.00                1
# 2           35          H            M          6.00                1
# 3           02          H            M          6.00                1
# 4           40          U            F          2.00                0
#
#   OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0              N             0           9.00                655
# 1              N             0           1.00                475
# 2              B            11           9.00               1117
# 3              B             1           7.00               2257
# 4              B             0           9.00                789
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      219                  77              12671
# 1                      227                  70              10221
# 2                      544                  87              18212
# 3                      485                  84              17885
# 4                      413                  97              14123
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0              46              24              53         0
# 1               0              30              33              29         1
# 2               1              27              70              21         0
# 3               0              43              28              41         1
# 4               0              31              16               7         0
#
#    RECENT_STAR_STATUS RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                   A                      1
# 1                   1                   S                      2
# 2                   0                   F                      1
# 3                  10                   A                      1
# 4                   0                   A                      3
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                  0.07                21.00                       0.00
# 1                  0.35                10.00                       0.50
# 2                  0.08                20.00                       0.20
# 3                  0.33                 8.83                       0.44
# 4                  0.28                 5.40                       0.22
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     10.00                      7
# 2                     20.00                      1
# 3                      8.75                      6
# 4                      6.00                      5
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           5                        22.00
# 2                           1                        20.00
# 3                           4                        19.00
# 4                           2                        20.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  11             25                103.00
# 1                  44            110                186.00
# 2                  13             39                 76.00
# 3                  42            114                247.00
# 4                  15             43                 70.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                    7                  14.71                16.00
# 1                   31                   6.00                 9.00
# 2                    9                   8.44                15.00
# 3                   38                   6.50                 5.00
# 4                   12                   5.83                 7.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  21.00                   5.00          21.00             4
# 1                  11.00                   2.00          10.00             9
# 2                  20.00                   5.00          20.00             5
# 3                  10.00                   5.00          10.00            10
# 4                  10.00                   3.00           5.00             5
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              10                      26                       90
# 1              22                      22                      129
# 2              14                      20                       87
# 3              24                      19                      129
# 4              12                      18                       85
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0          14.71               2
# 1           6.00              14
# 2           8.44               1
# 3           6.50              22
# 4           5.83               2

# %%
# Merge the Final data to the newest_data to do some demographics profiling
Final_ouput = pd.merge(newest_data,
                 Final,
                 on='CONTROL_NUMBER',how = 'inner')
Final_ouput.head()
# Out:
#    CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE URBANICITY SES  \
# 0             139                  101      71.00         0          R   2
# 1             142                  137      71.00         0          R   2
# 2             282                   17      30.00         0          T   1
# 3             368                  137      75.00         0          U   1
# 4             387                    5      71.00         0          T   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           46          U            F          5.00                0
# 1           43          U            F          5.00                1
# 2           35          H            M          6.00                1
# 3           02          H            M          6.00                1
# 4           40          U            F          2.00                0
#
#   OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0              N             0           9.00                655
# 1              N             0           1.00                475
# 2              B            11           9.00               1117
# 3              B             1           7.00               2257
# 4              B             0           9.00                789
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      219                  77              12671
# 1                      227                  70              10221
# 2                      544                  87              18212
# 3                      485                  84              17885
# 4                      413                  97              14123
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0              46              24              53         0
# 1               0              30              33              29         1
# 2               1              27              70              21         0
# 3               0              43              28              41         1
# 4               0              31              16               7         0
#
#    RECENT_STAR_STATUS RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                   A                      1
# 1                   1                   S                      2
# 2                   0                   F                      1
# 3                  10                   A                      1
# 4                   0                   A                      3
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                  0.07                21.00                       0.00
# 1                  0.35                10.00                       0.50
# 2                  0.08                20.00                       0.20
# 3                  0.33                 8.83                       0.44
# 4                  0.28                 5.40                       0.22
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     10.00                      7
# 2                     20.00                      1
# 3                      8.75                      6
# 4                      6.00                      5
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           5                        22.00
# 2                           1                        20.00
# 3                           4                        19.00
# 4                           2                        20.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  11             25                103.00
# 1                  44            110                186.00
# 2                  13             39                 76.00
# 3                  42            114                247.00
# 4                  15             43                 70.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                    7                  14.71                16.00
# 1                   31                   6.00                 9.00
# 2                    9                   8.44                15.00
# 3                   38                   6.50                 5.00
# 4                   12                   5.83                 7.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  21.00                   5.00          21.00             4
# 1                  11.00                   2.00          10.00             9
# 2                  20.00                   5.00          20.00             5
# 3                  10.00                   5.00          10.00            10
# 4                  10.00                   3.00           5.00             5
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              10                      26                       90
# 1              22                      22                      129
# 2              14                      20                       87
# 3              24                      19                      129
# 4              12                      18                       85
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT  Donation_Flag
# 0          14.71               2              0
# 1           6.00              14              0
# 2           8.44               1              0
# 3           6.50              22              0
# 4           5.83               2              0

# %%
Final_ouput.count()
# Out:
# CONTROL_NUMBER                 2148
# MONTHS_SINCE_ORIGIN            2148
# DONOR_AGE                      2148
# IN_HOUSE                       2148
# URBANICITY                     2148
# SES                            2148
# CLUSTER_CODE                   2148
# HOME_OWNER                     2148
# DONOR_GENDER                   2148
# INCOME_GROUP                   2148
# PUBLISHED_PHONE                2148
# OVERLAY_SOURCE                 2148
# MOR_HIT_RATE                   2148
# WEALTH_RATING                  2148
# MEDIAN_HOME_VALUE              2148
# MEDIAN_HOUSEHOLD_INCOME        2148
# PCT_OWNER_OCCUPIED             2148
# PER_CAPITA_INCOME              2148
# PCT_ATTRIBUTE1                 2148
# PCT_ATTRIBUTE2                 2148
# PCT_ATTRIBUTE3                 2148
# PCT_ATTRIBUTE4                 2148
# PEP_STAR                       2148
# RECENT_STAR_STATUS             2148
# RECENCY_STATUS_96NK            2148
# FREQUENCY_STATUS_97NK          2148
# RECENT_RESPONSE_PROP           2148
# RECENT_AVG_GIFT_AMT            2148
# RECENT_CARD_RESPONSE_PROP      2148
# RECENT_AVG_CARD_GIFT_AMT       2148
# RECENT_RESPONSE_COUNT          2148
# RECENT_CARD_RESPONSE_COUNT     2148
# MONTHS_SINCE_LAST_PROM_RESP    2148
# LIFETIME_CARD_PROM             2148
# LIFETIME_PROM                  2148
# LIFETIME_GIFT_AMOUNT           2148
# LIFETIME_GIFT_COUNT            2148
# LIFETIME_AVG_GIFT_AMT          2148
# LIFETIME_GIFT_RANGE            2148
# LIFETIME_MAX_GIFT_AMT          2148
# LIFETIME_MIN_GIFT_AMT          2148
# LAST_GIFT_AMT                  2148
# CARD_PROM_12                   2148
# NUMBER_PROM_12                 2148
# MONTHS_SINCE_LAST_GIFT         2148
# MONTHS_SINCE_FIRST_GIFT        2148
# FILE_AVG_GIFT                  2148
# FILE_CARD_GIFT                 2148
# Donation_Flag                  2148
# dtype: int64

# %%
#scores.count()
#pred_train.count()
#Score_data.CustomerKey.count()
#Final.head(5)
#clf.predict_proba(features)
#clf.predict_proba(features)[:,1]
prob = scores[['SCORE']].values.squeeze()

# %%
prob
# Out:
# array([0.19811578, 0.282032  , 0.20896756, ..., 0.34986733, 0.2175592 ,
#        0.32939052])

# %%
#, 'Score':scores.SCORE, 'Decile':scores.DECILE
#Final_ = pd.DataFrame({'CustomerKey':Score_data.CustomerKey,'Score':clf.predict_proba(features)[:,1]})
#Final_ = pd.DataFrame({'CustomerKey':Score_data.CustomerKey,'SCORE':clf.predict_proba(features)[:,1]})
Final_ = pd.DataFrame({'CONTROL_NUMBER':Score_data_sel.CONTROL_NUMBER,'Donation_Probability':prob})

# %%
Final_.head(5)
# Out:
#    CONTROL_NUMBER  Donation_Probability
# 0             139                  0.20
# 1             142                  0.28
# 2             282                  0.21
# 3             368                  0.29
# 4             387                  0.24

# %%
# Merge the probabilities to the
Final = pd.merge(Final_ouput,
                 Final_,
                 on='CONTROL_NUMBER',how = 'inner')
Final.head()
# Out:
#    CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE URBANICITY SES  \
# 0             139                  101      71.00         0          R   2
# 1             142                  137      71.00         0          R   2
# 2             282                   17      30.00         0          T   1
# 3             368                  137      75.00         0          U   1
# 4             387                    5      71.00         0          T   2
#
#   CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  PUBLISHED_PHONE  \
# 0           46          U            F          5.00                0
# 1           43          U            F          5.00                1
# 2           35          H            M          6.00                1
# 3           02          H            M          6.00                1
# 4           40          U            F          2.00                0
#
#   OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# 0              N             0           9.00                655
# 1              N             0           1.00                475
# 2              B            11           9.00               1117
# 3              B             1           7.00               2257
# 4              B             0           9.00                789
#
#    MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                      219                  77              12671
# 1                      227                  70              10221
# 2                      544                  87              18212
# 3                      485                  84              17885
# 4                      413                  97              14123
#
#    PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  \
# 0               0              46              24              53         0
# 1               0              30              33              29         1
# 2               1              27              70              21         0
# 3               0              43              28              41         1
# 4               0              31              16               7         0
#
#    RECENT_STAR_STATUS RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  \
# 0                   0                   A                      1
# 1                   1                   S                      2
# 2                   0                   F                      1
# 3                  10                   A                      1
# 4                   0                   A                      3
#
#    RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                  0.07                21.00                       0.00
# 1                  0.35                10.00                       0.50
# 2                  0.08                20.00                       0.20
# 3                  0.33                 8.83                       0.44
# 4                  0.28                 5.40                       0.22
#
#    RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                      0.00                      1
# 1                     10.00                      7
# 2                     20.00                      1
# 3                      8.75                      6
# 4                      6.00                      5
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           5                        22.00
# 2                           1                        20.00
# 3                           4                        19.00
# 4                           2                        20.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  11             25                103.00
# 1                  44            110                186.00
# 2                  13             39                 76.00
# 3                  42            114                247.00
# 4                  15             43                 70.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                    7                  14.71                16.00
# 1                   31                   6.00                 9.00
# 2                    9                   8.44                15.00
# 3                   38                   6.50                 5.00
# 4                   12                   5.83                 7.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  21.00                   5.00          21.00             4
# 1                  11.00                   2.00          10.00             9
# 2                  20.00                   5.00          20.00             5
# 3                  10.00                   5.00          10.00            10
# 4                  10.00                   3.00           5.00             5
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              10                      26                       90
# 1              22                      22                      129
# 2              14                      20                       87
# 3              24                      19                      129
# 4              12                      18                       85
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT  Donation_Flag  Donation_Probability
# 0          14.71               2              0                  0.20
# 1           6.00              14              0                  0.28
# 2           8.44               1              0                  0.21
# 3           6.50              22              0                  0.29
# 4           5.83               2              0                  0.24

# %%
# COMMERCIAL VALUE OF DONORS

# %%
path = "C:/Users/EO/Desktop/Josh Folder/downloads/ML ASSIGNMENT/Donor Raw Data_ML with Python.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 0         0       nan               5                  101      87.00
# 1         1     10.00              12                  137      79.00
# 2         0       nan              37                  113      75.00
# 3         0       nan              38                   92        nan
# 4         0       nan              41                  101      74.00
#
#    IN_HOUSE URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  INCOME_GROUP  \
# 0         0          ?   ?            .          H            M          2.00
# 1         0          R   2           45          H            M          7.00
# 2         0          S   1           11          H            F          5.00
# 3         0          U   2           04          H            F          6.00
# 4         0          R   2           49          U            F          2.00
#
#    PUBLISHED_PHONE OVERLAY_SOURCE  MOR_HIT_RATE  WEALTH_RATING  \
# 0                0              P             0            nan
# 1                0              P             0           3.00
# 2                0              P             0           9.00
# 3                1              B             0           4.00
# 4                1              B             8           5.00
#
#    MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# 0                554                      294                  76
# 1                334                      212                  72
# 2               2388                      405                  63
# 3               1688                      153                   3
# 4                514                      328                  90
#
#    PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# 0              11855               0               0               0
# 1              10385               0              41              21
# 2              30855               0              25              26
# 3              16342               0              25              32
# 4              12107               0              33              36
#
#    PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0               0         1                   0                   A
# 1              31         1                   1                   S
# 2              57         1                   1                   S
# 3              42         1                   0                   A
# 4              37         0                   0                   A
#
#    FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                      1                  0.07                15.00
# 1                      2                  0.23                15.00
# 2                      3                  0.41                21.67
# 3                      3                  0.47                13.44
# 4                      1                  0.10                17.50
#
#    RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                       0.00                      0.00                      1
# 1                       0.25                     15.00                      4
# 2                       0.55                     22.67                      9
# 3                       0.40                     13.50                      9
# 4                       0.11                     10.00                      2
#
#    RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                           0                        26.00
# 1                           2                        11.00
# 2                           6                        14.00
# 3                           4                        11.00
# 4                           1                        18.00
#
#    LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                  19             45                297.00
# 1                  32             90                368.00
# 2                  44            119                603.00
# 3                  31             96                435.00
# 4                  30             83                106.00
#
#    LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                   35                   8.49                15.00
# 1                   25                  14.72                20.00
# 2                   36                  16.75                23.00
# 3                   37                  11.76                14.00
# 4                   12                   8.83                20.00
#
#    LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  CARD_PROM_12  \
# 0                  20.00                   5.00          15.00             5
# 1                  25.00                   5.00          17.00             7
# 2                  28.00                   5.00          19.00            11
# 3                  17.00                   3.00          15.00            11
# 4                  25.00                   5.00          25.00             6
#
#    NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# 0              12                      26                       92
# 1              21                       7                      122
# 2              32                       6                      105
# 3              33                       6                       92
# 4              19                      18                       92
#
#    FILE_AVG_GIFT  FILE_CARD_GIFT
# 0           8.49               7
# 1          14.72              12
# 2          16.75              16
# 3          11.76              12
# 4           8.83               3

# %%
df.describe()
# Out:
#        TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# count  19372.00   4843.00        19372.00             19372.00   14577.00
# mean       0.25     15.62        96546.23                73.41      58.92
# std        0.43     12.45        55830.64                41.26      16.67
# min        0.00      1.00            5.00                 5.00       0.00
# 25%        0.00     10.00        48289.00                29.00      47.00
# 50%        0.00     13.00        96937.00                65.00      60.00
# 75%        0.25     20.00       145429.50               113.00      73.00
# max        1.00    200.00       191779.00               137.00      87.00
#
#        IN_HOUSE  INCOME_GROUP  PUBLISHED_PHONE  MOR_HIT_RATE  WEALTH_RATING  \
# count  19372.00      14980.00         19372.00      19372.00       10562.00
# mean       0.07          3.91             0.50          3.36           5.01
# std        0.26          1.86             0.50          9.50           2.82
# min        0.00          1.00             0.00          0.00           0.00
# 25%        0.00          2.00             0.00          0.00           3.00
# 50%        0.00          4.00             0.00          0.00           5.00
# 75%        0.00          5.00             1.00          3.00           7.00
# max        1.00          7.00             1.00        241.00           9.00
#
#        MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# count           19372.00                 19372.00            19372.00
# mean             1079.87                   341.97               69.70
# std               960.75                   164.21               21.71
# min                 0.00                     0.00                0.00
# 25%               518.00                   232.00               60.00
# 50%               747.00                   311.00               76.00
# 75%              1227.00                   417.00               85.00
# max              6000.00                  1500.00               99.00
#
#        PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  \
# count           19372.00        19372.00        19372.00        19372.00
# mean            15857.33            1.03           30.57           29.60
# std              8710.63            4.92           11.42           15.12
# min                 0.00            0.00            0.00            0.00
# 25%             10869.00            0.00           25.00           20.00
# 50%             13816.50            0.00           31.00           29.00
# 75%             18308.25            0.00           37.00           39.00
# max            174523.00           97.00           99.00           99.00
#
#        PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS  FREQUENCY_STATUS_97NK  \
# count        19372.00  19372.00            19372.00               19372.00
# mean            32.85      0.50                0.93                   1.98
# std             17.84      0.50                2.55                   1.10
# min              0.00      0.00                0.00                   1.00
# 25%             21.00      0.00                0.00                   1.00
# 50%             32.00      1.00                0.00                   2.00
# 75%             43.00      1.00                1.00                   3.00
# max             99.00      1.00               22.00                   4.00
#
#        RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# count              19372.00             19372.00                   19372.00
# mean                   0.19                15.37                       0.23
# std                    0.11                10.17                       0.19
# min                    0.00                 0.00                       0.00
# 25%                    0.10                10.00                       0.10
# 50%                    0.17                14.00                       0.20
# 75%                    0.25                20.00                       0.33
# max                    1.00               260.00                       1.00
#
#        RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# count                  19372.00               19372.00
# mean                      11.69                   3.04
# std                       10.83                   2.05
# min                        0.00                   0.00
# 25%                        5.00                   2.00
# 50%                       10.14                   3.00
# 75%                       16.00                   4.00
# max                      300.00                  16.00
#
#        RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# count                    19372.00                     19126.00
# mean                         1.73                        19.04
# std                          1.54                         3.42
# min                          0.00                       -12.00
# 25%                          1.00                        17.00
# 50%                          1.00                        18.00
# 75%                          2.00                        21.00
# max                          9.00                        36.00
#
#        LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# count            19372.00       19372.00              19372.00
# mean                18.67          47.57                104.43
# std                  8.56          22.95                105.72
# min                  2.00           5.00                 15.00
# 25%                 11.00          28.00                 42.00
# 50%                 18.00          47.00                 79.00
# 75%                 26.00          64.00                132.00
# max                 56.00         194.00               3775.00
#
#        LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# count             19372.00               19372.00             19372.00
# mean                  9.98                  12.86                11.59
# std                   8.69                   8.79                15.12
# min                   1.00                   1.36                 0.00
# 25%                   4.00                   8.00                 5.00
# 50%                   8.00                  11.20                10.00
# 75%                  14.00                  15.00                15.00
# max                  95.00                 450.00               997.00
#
#        LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# count               19372.00               19372.00       19372.00
# mean                   19.21                   7.62          16.58
# std                    16.10                   7.96          11.98
# min                     5.00                   0.00           0.00
# 25%                    12.00                   3.00          10.00
# 50%                    16.00                   5.00          15.00
# 75%                    21.00                  10.00          20.00
# max                  1000.00                 450.00         450.00
#
#        CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# count      19372.00        19372.00                19372.00
# mean           5.37           12.90                   18.19
# std            1.26            4.64                    4.03
# min            0.00            2.00                    4.00
# 25%            5.00           11.00                   16.00
# 50%            6.00           12.00                   18.00
# 75%            6.00           13.00                   20.00
# max           17.00           64.00                   27.00
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# count                 19372.00       19372.00        19372.00
# mean                     69.48          12.86            5.27
# std                      37.57           8.79            4.61
# min                      15.00           1.36            0.00
# 25%                      33.00           8.00            2.00
# 50%                      65.00          11.20            4.00
# 75%                     105.00          15.00            8.00
# max                     260.00         450.00           41.00

# %%
### From the diagram we can see that TARGET_D, 
##which is defined as the amount of money actual donors donated, has an average of 15.62.Let's round up to 16
##We can take this value and multiply it by a 100 donors predicted to donate to find out our commercial value for a 100 donors
##The commercial value is 1600
